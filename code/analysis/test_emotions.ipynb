# %%
import spacy
import numpy as np
import matplotlib.pyplot as plt
import glob
import re
from collections import Counter
from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt

import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from analysis_code.analyze_corpus import *

# %%
Directory = '/home/dashi/lulu/corpus/NRC-Emotion-Lexicon-v0.92/'
# Each line has the following format:
# <term>--<NearSynonyms><tab><AffectCategory><tab><AssociationFlag>
# <term> is a word for which emotion associations are provided;
# <NearSynonyms> is a set of one to three comma-separated words that indicate the sense of the <term>. The affect annotations are for this sense of the term.
# <AffectCategory> is one of eight emotions (anger, fear, anticipation, trust, surprise, sadness, joy, or disgust) or one of two polarities (negative or positive);
# <AssociationFlag> has one of two possible values: 0 or 1. 0 indicates that the target word has no association with affect category, whereas 1 indicates an association.
WordSenseFile = 'NRC-Emotion-Lexicon-Senselevel-v0.92.txt'
# Each line has the following format:
# <term><tab><AffectCategory><tab><AssociationFlag>
# <term> is a word for which emotion associations are provided;
# <AffectCategory> is one of eight emotions (anger, fear, anticipation, trust, surprise, sadness, joy, or disgust) or one of two polarities (negative or positive);
# <AssociationFlag> has one of two possible values: 0 or 1. 0 indicates that the target word has no association with affect category, whereas 1 indicates an association.
WordFile = 'NRC-Emotion-Lexicon-Wordlevel-v0.92.txt'

outFile ='Generated-EmotionWords.txt'

# %%
def processSenseFile(filename):
    '''
    Create a list of emotion words which has non-zero polarity
    input : sense file
    return : set of emotion words
    '''
    emotionWords = set([])
    with open(filename, 'r', errors='replace') as f:
        line = f.readline()
        while line:
            words = line.strip().split()
            if len(words) == 5: 
                category = words[3]
                sentiment = words[4]
                word = re.split(r'(\W+)', words[0])[0]
                if (word == 'paraphrase'): 
                    print(words)
                if ('positive' == category or 'negative' == category) and ('1' == sentiment):
                    emotionWords.add(word)
            line = f.readline()            
    return emotionWords

def processMoreSenseFile(filename):
    '''
    Create a list of emotion words which has non-zero polarity
    input : sense file
    return : dictionary of emotion word : emotions, scores
    '''
    emotionScores = {}
    with open(filename, 'r', errors='replace') as f:
        i = 1
        line = f.readline()
        count = 0
        while line: 
            words = line.strip().split()
            word = re.split(r'(\W+)', words[0])[0]
            sentiment = words[-1]
            category = words[-2]
            
            if ('positive' == category or 'negative' == category) and ('1' == sentiment):
                emotionScores[word] = 0
            elif ('positive' != category and 'negative' != category) and ('1' == sentiment):
                count += 1
            if i % 8 == 0: 
                if word in emotionScores: 
                    emotionScores[word] = count
                count = 0
            line = f.readline()
            i += 1 
    return emotionScores

def processWordFile(filename):
    '''
    input : word file 
    return : set of emotion words
    '''
    emotionWords = set([])
    with open(filename, 'r', errors='replace') as f:
        line = f.readline()
        while line:
            words = line.strip().split()
            if len(words) == 3: 
                word = words[0]
                category = words[1]
                sentiment = words[2]
                if ('positive' == category or 'negative' == category) and ('1' == sentiment):
                    emotionWords.add(word)
            line = f.readline()            
    return emotionWords


def generateSentimentScore(filename):
    '''
    input : sense file 
    return : set of emotion words
    '''
    emotionWords = {}
    with open(filename, 'r', errors='replace') as f:
        line = f.readline()
        i = 1 
        numcat = 0
        polarity = 0
        word = ''
        while line:
            # new word
            if (i % 10 == 0): 
                emotionWords = (word, numcat, polarity)
                numcat = 0
                polarity = 0
                    
            words = line.strip().split()                
            if len(words) == 5: 
                category = words[3]
                sentiment = words[4]
                word = re.split(r'(\W+)', words[0])[0]
                if ('1' == sentiment):
                    if ('positive' == category or 'negative' == category):
                        polarity = 1
                    else: 
                        numcat += 1 
            line = f.readline()  
            i += 1
    return emotionWords

# def filterScore(emotionWords):
#     result = {}
#     for e in emotionWords: 
#         word = e[0] 
#         numcat = e[1]
#         polarity = e[2]
#         if (polarity != 0): 
#             result.add(word)
#     return {k:v for k, v in emotionWords.items() if v[1] == 1}

# %%
'''
Create emotion word set, no associations, feelings, or sentiment categories
'''
# file1 = Directory + WordSenseFile
words = processSenseFile(Directory + 'NRC-example_1.txt')
print(words)
# Out:
# {'guide', 'harm'}

# %%
'''
Create emotion word set, no associations, feelings, or sentiment categories
'''
words = processWordFile(Directory + 'NRC-example_2.txt')
print(words)
# Out:
# {'abandon'}

# %%
senseWords = processSenseFile(Directory + WordSenseFile)
print('number of emotion words : ' + str(len(senseWords)))
print('first 10 words : ' + str(list(senseWords)[0:10]))
# Out:
# ['paraphrase--copy,', 'burlesque,', 'travesty', 'fear', '0']
# ['paraphrase--copy,', 'burlesque,', 'travesty', 'anger', '0']
# ['paraphrase--copy,', 'burlesque,', 'travesty', 'anticip', '0']
# ['paraphrase--copy,', 'burlesque,', 'travesty', 'trust', '0']
# ['paraphrase--copy,', 'burlesque,', 'travesty', 'surprise', '0']
# ['paraphrase--copy,', 'burlesque,', 'travesty', 'positive', '0']
# ['paraphrase--copy,', 'burlesque,', 'travesty', 'negative', '0']
# ['paraphrase--copy,', 'burlesque,', 'travesty', 'sadness', '0']
# ['paraphrase--copy,', 'burlesque,', 'travesty', 'disgust', '0']
# ['paraphrase--copy,', 'burlesque,', 'travesty', 'joy', '0']
# ['paraphrase--interpretation,', 'equivalent,', 'synonym', 'fear', '0']
# ['paraphrase--interpretation,', 'equivalent,', 'synonym', 'anger', '0']
# ['paraphrase--interpretation,', 'equivalent,', 'synonym', 'anticip', '0']
# ['paraphrase--interpretation,', 'equivalent,', 'synonym', 'trust', '0']
# ['paraphrase--interpretation,', 'equivalent,', 'synonym', 'surprise', '0']
# ['paraphrase--interpretation,', 'equivalent,', 'synonym', 'positive', '1']
# ['paraphrase--interpretation,', 'equivalent,', 'synonym', 'negative', '1']
# ['paraphrase--interpretation,', 'equivalent,', 'synonym', 'sadness', '0']
# ['paraphrase--interpretation,', 'equivalent,', 'synonym', 'disgust', '0']
# ['paraphrase--interpretation,', 'equivalent,', 'synonym', 'joy', '0']
# ['paraphrase--imitation,', 'caricature,', 'parody', 'fear', '0']
# ['paraphrase--imitation,', 'caricature,', 'parody', 'anger', '0']
# ['paraphrase--imitation,', 'caricature,', 'parody', 'anticip', '0']
# ['paraphrase--imitation,', 'caricature,', 'parody', 'trust', '0']
# ['paraphrase--imitation,', 'caricature,', 'parody', 'surprise', '0']
# ['paraphrase--imitation,', 'caricature,', 'parody', 'positive', '0']
# ['paraphrase--imitation,', 'caricature,', 'parody', 'negative', '0']
# ['paraphrase--imitation,', 'caricature,', 'parody', 'sadness', '0']
# ['paraphrase--imitation,', 'caricature,', 'parody', 'disgust', '0']
# ['paraphrase--imitation,', 'caricature,', 'parody', 'joy', '0']
# number of emotion words : 1900
# first 10 words : ['paraphrase', 'virulence', 'aggressor', 'complexity', 'tolerate', 'prove', 'erratum', 'theism', 'delayed', 'innovate']

# %%
wordWords = processWordFile(Directory + WordFile)
print('number of emotion words : ' + str(len(wordWords)))
print('first 10 words : ' + str(list(wordWords)[0:10]))
# Out:
# number of emotion words : 5555
# first 10 words : ['unique', 'vengeful', 'amusing', 'pay', 'informer', 'plight', 'overpaid', 'income', 'eagerness', 'knotted']

# %%
len(senseWords & wordWords)
# Out:
# 1894

# %%
'''
Use sense words only
'''
with open(Directory + outFile, "w") as outfile:
    for w in senseWords:
        outfile.write(w + '\n') 
outfile.close()

# %%
senseScore = generateSentimentScore(Directory + WordSenseFile)

# %%
senseScore
# Out:
# {'paraphrase': (0, 0),
#  'porosity': (0, 0),
#  'invaluable': (0, 0),
#  'virulence': (2, 1),
#  'complexity': (0, 1),
#  'chapter': (0, 0),
#  'untranslated': (0, 0),
#  'swell': (0, 0),
#  'presumption': (1, 0),
#  'hood': (0, 0),
#  'tolerate': (2, 1),
#  'prove': (0, 1),
#  'saving': (0, 0),
#  'aggressor': (2, 1),
#  'theism': (1, 1),
#  'sphere': (0, 0),
#  'delayed': (0, 1),
#  'backfire': (0, 0),
#  'curtain': (0, 0),
#  'weird': (0, 0),
#  'innovate': (0, 1),
#  'act': (0, 0),
#  'resort': (0, 0),
#  'void': (0, 0),
#  'disregarded': (1, 1),
#  'fair': (0, 1),
#  'press': (0, 0),
#  'pronounce': (0, 0),
#  'hate': (3, 1),
#  'gob': (1, 0),
#  'horticultural': (0, 0),
#  'organization': (0, 1),
#  'foolish': (0, 0),
#  'vegetarianism': (0, 0),
#  'association': (0, 0),
#  'phony': (0, 1),
#  'port': (0, 0),
#  'vista': (0, 0),
#  'dermatology': (0, 0),
#  'tribulation': (2, 1),
#  'spill': (0, 0),
#  'sway': (0, 0),
#  'failing': (3, 1),
#  'economics': (0, 0),
#  'gills': (0, 0),
#  'politics': (0, 0),
#  'forearm': (2, 0),
#  'overtaken': (0, 0),
#  'estuary': (0, 0),
#  'homosexuality': (0, 1),
#  'flickering': (0, 0),
#  'meshes': (0, 0),
#  'toby': (0, 0),
#  'flurry': (0, 0),
#  'butt': (0, 1),
#  'commence': (0, 0),
#  'usual': (1, 0),
#  'favor': (0, 0),
#  'relief': (0, 1),
#  'perform': (0, 0),
#  'unimproved': (0, 1),
#  'academy': (0, 1),
#  'brooding': (0, 0),
#  'fell': (1, 1),
#  'tag': (0, 0),
#  'susceptibility': (1, 0),
#  'untoward': (1, 1),
#  'conjunction': (0, 0),
#  'dictatorial': (1, 1),
#  'monster': (1, 1),
#  'sturdy': (0, 1),
#  'variations': (0, 0),
#  'sib': (1, 0),
#  'cooling': (0, 0),
#  'offered': (0, 0),
#  'taste': (0, 0),
#  'dam': (0, 0),
#  'danger': (2, 1),
#  'wind': (0, 0),
#  'anaconda': (2, 1),
#  'apologize': (0, 0),
#  'opiate': (0, 1),
#  'fill': (1, 0),
#  'speculative': (0, 0),
#  'size': (0, 0),
#  'erratum': (1, 1),
#  'warrant': (0, 0),
#  'conscientious': (1, 1),
#  'enamel': (0, 0),
#  'patience': (0, 0),
#  'tropical': (0, 0),
#  'paint': (0, 0),
#  'seasoning': (0, 0),
#  'exile': (0, 0),
#  'roll': (0, 0),
#  'strengthening': (1, 1),
#  'dormitory': (0, 0),
#  'rise': (0, 0),
#  'willow': (0, 0),
#  'tripping': (0, 0),
#  'compass': (1, 0),
#  'rap': (0, 0),
#  'benzene': (0, 0),
#  'bookstore': (0, 0),
#  'lymphatic': (0, 0),
#  'inspiration': (0, 0),
#  'jimmy': (0, 0),
#  'infraction': (0, 0),
#  'cobble': (0, 0),
#  'overture': (0, 0),
#  'gauging': (1, 0),
#  'staccato': (0, 1),
#  'dyke': (0, 0),
#  'birthplace': (1, 1),
#  'separation': (0, 0),
#  'lending': (0, 0),
#  'familiarity': (0, 0),
#  'ancient': (0, 1),
#  'presentable': (0, 1),
#  'distortion': (0, 1),
#  'libido': (0, 0),
#  'advise': (1, 1),
#  'milligram': (0, 0),
#  'civic': (0, 0),
#  'uncover': (1, 0),
#  'ghost': (1, 0),
#  'romp': (0, 1),
#  'parallax': (0, 0),
#  'object': (0, 0),
#  'broadcast': (0, 0),
#  'instrumental': (0, 0),
#  'jack': (0, 0),
#  'revise': (0, 0),
#  'minivan': (0, 0),
#  'fasting': (1, 0),
#  'company': (0, 0),
#  'saloon': (0, 0),
#  'shockingly': (1, 0),
#  'dogged': (0, 1),
#  'weakened': (0, 1),
#  'recognizable': (0, 1),
#  'wedge': (0, 0),
#  'agency': (0, 0),
#  'acquiring': (1, 1),
#  'prestige': (0, 0),
#  'doit': (0, 1),
#  'reorganize': (0, 0),
#  'contentious': (0, 0),
#  'outrageous': (0, 0),
#  'sum': (0, 0),
#  'eavesdropping': (0, 1),
#  'treat': (0, 1),
#  'sour': (0, 1),
#  'droll': (0, 0),
#  'kos': (0, 0),
#  'apportionment': (0, 0),
#  'subvert': (0, 0),
#  'etiology': (0, 0),
#  'behavior': (0, 0),
#  'adjunct': (0, 0),
#  'unimaginable': (0, 0),
#  'planting': (0, 0),
#  'punctual': (0, 0),
#  'words': (1, 1),
#  'oppressive': (0, 0),
#  'mobilization': (0, 0),
#  'honeycomb': (0, 0),
#  'undo': (0, 1),
#  'fossils': (0, 0),
#  'slates': (0, 0),
#  'descendant': (0, 0),
#  'admiration': (0, 0),
#  'make': (0, 0),
#  'cyanide': (1, 1),
#  'vanish': (0, 0),
#  'impression': (0, 1),
#  'rail': (0, 0),
#  'slaughtering': (5, 1),
#  'unorganized': (0, 0),
#  'materials': (0, 0),
#  'urge': (0, 0),
#  'pool': (0, 0),
#  'permanence': (0, 0),
#  'organism': (0, 0),
#  'eve': (0, 0),
#  'swinging': (0, 0),
#  'regular': (0, 0),
#  'bearing': (0, 0),
#  'friend': (0, 0),
#  'inspire': (0, 0),
#  'reactionary': (0, 0),
#  'fiduciary': (0, 0),
#  'pay': (0, 0),
#  'rarity': (0, 0),
#  'aimless': (0, 0),
#  'humanities': (0, 0),
#  'interruption': (0, 0),
#  'itching': (0, 0),
#  'liabilities': (0, 0),
#  'dreaming': (0, 0),
#  'scaffold': (0, 0),
#  'pavilion': (0, 0),
#  'poignant': (0, 0),
#  'blower': (0, 1),
#  'vindicated': (0, 1),
#  'disorder': (0, 0),
#  'idiot': (1, 1),
#  'scout': (0, 0),
#  'multiplication': (0, 0),
#  'single': (0, 0),
#  'methanol': (0, 1),
#  'dodging': (0, 0),
#  'moronic': (0, 1),
#  'lumbar': (0, 0),
#  'advance': (0, 1),
#  'elaborate': (0, 0),
#  'constitutionality': (0, 0),
#  'aberrant': (0, 0),
#  'hug': (1, 1),
#  'ingot': (0, 0),
#  'column': (0, 0),
#  'farce': (0, 1),
#  'bang': (5, 1),
#  'tablet': (0, 0),
#  'scan': (0, 0),
#  'approximating': (0, 0),
#  'tat': (0, 0),
#  'unsettled': (0, 0),
#  'prowess': (0, 0),
#  'grudge': (1, 1),
#  'spatula': (0, 0),
#  'olfactory': (1, 1),
#  'cumbersome': (1, 1),
#  'crack': (0, 0),
#  'reassuring': (0, 0),
#  'pause': (1, 0),
#  'refuse': (0, 1),
#  'residences': (0, 0),
#  'accomplice': (1, 0),
#  'salty': (0, 0),
#  'stone': (0, 0),
#  'addressee': (0, 0),
#  'pump': (0, 0),
#  'vanished': (3, 1),
#  'director': (0, 0),
#  'notation': (0, 0),
#  'rubbish': (1, 1),
#  'jerk': (2, 0),
#  'centralize': (1, 0),
#  'resign': (0, 0),
#  'element': (0, 0),
#  'untrue': (0, 0),
#  'pundit': (0, 0),
#  'transformation': (0, 0),
#  'maneuvering': (0, 0),
#  'unacceptable': (1, 1),
#  'dock': (0, 0),
#  'firm': (0, 0),
#  'collect': (1, 0),
#  'blighted': (2, 1),
#  'succession': (0, 0),
#  'nib': (0, 0),
#  'roughness': (0, 1),
#  'circulation': (0, 0),
#  'construct': (0, 1),
#  'disgust': (0, 0),
#  'dwarfed': (2, 1),
#  'admixture': (0, 0),
#  'catholic': (0, 0),
#  'breech': (0, 0),
#  'enema': (1, 0),
#  'impotence': (2, 1),
#  'desperation': (0, 0),
#  'rake': (0, 0),
#  'depository': (1, 0),
#  'probe': (0, 0),
#  'grieve': (0, 0),
#  'receipts': (0, 0),
#  'harmony': (0, 1),
#  'express': (0, 0),
#  'induced': (0, 0),
#  'dime': (0, 0),
#  'moderate': (0, 0),
#  'parenchyma': (0, 0),
#  'fascination': (0, 0),
#  'forecast': (0, 0),
#  'speedway': (0, 0),
#  'donor': (1, 0),
#  'townhouse': (0, 0),
#  'cutting': (4, 1),
#  'rout': (0, 1),
#  'riot': (2, 1),
#  'endowed': (0, 1),
#  'outbreak': (0, 0),
#  'dog': (0, 0),
#  'shire': (0, 0),
#  'compost': (1, 1),
#  'digest': (0, 0),
#  'jubilee': (0, 0),
#  'standoff': (2, 1),
#  'club': (0, 0),
#  'walk': (0, 0),
#  'bitterly': (3, 1),
#  'soc': (0, 0),
#  'main': (0, 0),
#  'completion': (0, 0),
#  'ken': (0, 1),
#  'remarkably': (0, 1),
#  'figure': (0, 0),
#  'spy': (0, 0),
#  'refusing': (0, 0),
#  'darn': (0, 0),
#  'judge': (0, 0),
#  'moldy': (0, 0),
#  'disparage': (0, 0),
#  'sentinel': (0, 0),
#  'attacking': (5, 1),
#  'image': (0, 0),
#  'halting': (2, 1),
#  'pickle': (0, 1),
#  'surroundings': (0, 0),
#  'energy': (0, 0),
#  'revisit': (0, 0),
#  'pregnancy': (1, 1),
#  'fraternal': (0, 0),
#  'cooperation': (0, 1),
#  'modesty': (0, 1),
#  'slide': (0, 0),
#  'gossip': (0, 0),
#  'strive': (1, 0),
#  'toothless': (0, 0),
#  'stripe': (0, 0),
#  'bull': (0, 0),
#  'household': (0, 0),
#  'visor': (3, 0),
#  'crash': (0, 0),
#  'presence': (0, 0),
#  'producing': (0, 1),
#  'serpent': (2, 1),
#  'grain': (0, 0),
#  'retiring': (1, 0),
#  'publication': (0, 0),
#  'conic': (0, 0),
#  'haunt': (1, 1),
#  'semblance': (0, 0),
#  'hiss': (0, 0),
#  'illustrate': (0, 0),
#  'readiness': (2, 1),
#  'equivalent': (0, 0),
#  'denied': (2, 1),
#  'corner': (0, 0),
#  'stamina': (0, 0),
#  'mir': (0, 0),
#  'dementia': (2, 1),
#  'theater': (0, 0),
#  'palpable': (0, 0),
#  'dispersion': (0, 0),
#  'ovary': (0, 0),
#  'decoration': (1, 0),
#  'pretending': (1, 1),
#  'courtesy': (0, 0),
#  'incompetence': (0, 0),
#  'jaguar': (0, 0),
#  'raise': (0, 0),
#  'assumption': (0, 0),
#  'fitness': (0, 0),
#  'carve': (0, 0),
#  'handy': (0, 0),
#  'bag': (0, 0),
#  'soaking': (0, 0),
#  'recombinant': (0, 0),
#  'innocuous': (0, 0),
#  'fenced': (1, 0),
#  'studded': (0, 0),
#  'marshal': (0, 0),
#  'plain': (0, 0),
#  'resisting': (0, 0),
#  'angel': (3, 1),
#  'coexistence': (0, 0),
#  'grant': (2, 1),
#  'pen': (0, 0),
#  'tritium': (0, 0),
#  'parquet': (1, 0),
#  'demonstrated': (0, 0),
#  'nervous': (0, 0),
#  'dew': (0, 0),
#  'flashing': (0, 0),
#  'dissertation': (0, 0),
#  'cry': (0, 0),
#  'embryo': (0, 0),
#  'succeed': (1, 0),
#  'acknowledged': (0, 0),
#  'immaterial': (0, 0),
#  'dawn': (3, 1),
#  'fret': (1, 1),
#  'institution': (0, 0),
#  'efficient': (0, 0),
#  'marble': (0, 0),
#  'courses': (0, 0),
#  'study': (0, 1),
#  'unsatisfied': (1, 0),
#  'cut': (0, 0),
#  'flaw': (0, 1),
#  'flanked': (0, 0),
#  'plowed': (0, 0),
#  'concealment': (2, 1),
#  'rack': (1, 1),
#  'potter': (0, 0),
#  'enforcement': (0, 1),
#  'luxuriant': (0, 1),
#  'engrossed': (0, 0),
#  'plush': (0, 1),
#  'adequate': (0, 0),
#  'puma': (2, 0),
#  'word': (0, 0),
#  'disagreeing': (0, 1),
#  'intelligence': (0, 0),
#  'shell': (0, 0),
#  'analyzer': (0, 0),
#  'commodity': (0, 0),
#  'doublet': (1, 0),
#  'guide': (1, 1),
#  'facts': (1, 1),
#  'horrible': (0, 0),
#  'undermined': (0, 1),
#  'tipsy': (0, 1),
#  'suspense': (0, 0),
#  'pending': (0, 0),
#  'bask': (0, 0),
#  'conciliation': (0, 1),
#  'tenderness': (0, 1),
#  'incentive': (0, 0),
#  'marked': (0, 0),
#  'fecal': (1, 1),
#  'overlying': (0, 0),
#  'row': (1, 1),
#  'cipher': (0, 0),
#  'assimilate': (0, 0),
#  'heat': (0, 0),
#  'conditionally': (0, 0),
#  'welcomed': (0, 1),
#  'arbor': (0, 0),
#  'emotion': (0, 0),
#  'devolve': (0, 0),
#  'vertebral': (0, 0),
#  'fudge': (0, 1),
#  'unauthorized': (0, 0),
#  'instruct': (0, 0),
#  'introductory': (0, 0),
#  'recursively': (0, 0),
#  'vertigo': (1, 0),
#  'barrel': (0, 0),
#  'immaturity': (1, 1),
#  'aby': (0, 0),
#  'purchase': (0, 0),
#  'mineral': (0, 0),
#  'herald': (0, 0),
#  'punctuality': (0, 1),
#  'sphinx': (0, 0),
#  'damsel': (0, 0),
#  'armor': (2, 1),
#  'law': (1, 0),
#  'bomb': (0, 0),
#  'superimposed': (0, 0),
#  'squirrel': (0, 0),
#  'partisan': (0, 0),
#  'gallery': (0, 0),
#  'carry': (0, 0),
#  'geranium': (0, 1),
#  'fake': (0, 0),
#  'allowance': (0, 0),
#  'scale': (0, 0),
#  'dummy': (0, 1),
#  'overlay': (0, 0),
#  'inconsiderate': (0, 0),
#  'boot': (0, 0),
#  'toxicology': (0, 0),
#  'royal': (0, 0),
#  'cumulus': (0, 0),
#  'defined': (0, 0),
#  'restriction': (0, 0),
#  'burnout': (1, 0),
#  'eclipse': (0, 0),
#  'rope': (0, 0),
#  'letter': (0, 0),
#  'stationary': (0, 0),
#  'blunder': (0, 0),
#  'line': (0, 0),
#  'delineate': (0, 0),
#  'peridot': (0, 0),
#  'languish': (0, 1),
#  'porch': (0, 0),
#  'possess': (1, 0),
#  'wit': (0, 1),
#  'ovation': (1, 1),
#  'jackass': (0, 0),
#  'happy': (0, 1),
#  'overlaid': (0, 0),
#  'link': (0, 0),
#  'rawhide': (0, 0),
#  'insulate': (0, 0),
#  'impossible': (1, 1),
#  'venous': (0, 0),
#  'field': (0, 0),
#  'kudos': (0, 1),
#  'sparring': (0, 0),
#  'order': (0, 0),
#  'quote': (2, 1),
#  'limp': (0, 0),
#  'centrality': (0, 0),
#  'affliction': (0, 0),
#  'product': (0, 0),
#  'irregularity': (0, 0),
#  'blot': (0, 1),
#  'spit': (0, 0),
#  'silly': (0, 0),
#  'approach': (0, 0),
#  'charter': (0, 0),
#  'repository': (0, 0),
#  'float': (0, 0),
#  'rust': (0, 0),
#  'comprehend': (0, 0),
#  'confuse': (1, 1),
#  'reinforcement': (0, 0),
#  'cultivation': (0, 0),
#  'clutches': (0, 0),
#  'appliances': (0, 0),
#  'creation': (0, 0),
#  'environment': (0, 0),
#  'adieu': (0, 0),
#  'memorials': (1, 0),
#  'dolphin': (2, 1),
#  'kink': (0, 0),
#  'atlas': (0, 0),
#  'rollers': (0, 0),
#  'snarling': (1, 1),
#  'recesses': (1, 0),
#  'laboring': (0, 0),
#  'distress': (0, 0),
#  'unclaimed': (0, 0),
#  'ready': (1, 0),
#  'defiance': (0, 0),
#  'stays': (0, 0),
#  'cinch': (0, 0),
#  'hinge': (0, 0),
#  'radically': (0, 0),
#  'frequent': (0, 0),
#  'godly': (1, 1),
#  'recruiting': (0, 0),
#  'flatness': (1, 0),
#  'encrypt': (0, 0),
#  'pegs': (0, 0),
#  'cereal': (0, 0),
#  'indelible': (0, 0),
#  'preside': (0, 0),
#  'extant': (0, 0),
#  'monarchy': (0, 0),
#  'journal': (0, 0),
#  'herbarium': (0, 0),
#  'antibiotics': (0, 1),
#  'continuously': (0, 0),
#  'prod': (0, 0),
#  'uninfected': (0, 1),
#  'irritation': (3, 1),
#  'uncertainty': (2, 1),
#  'adjustment': (0, 0),
#  'concern': (0, 0),
#  'prog': (0, 0),
#  'chore': (1, 1),
#  'infinite': (0, 0),
#  'cup': (0, 0),
#  'feather': (0, 0),
#  'fractional': (1, 0),
#  'observance': (0, 0),
#  'sustenance': (0, 0),
#  'oversight': (0, 1),
#  'discovery': (0, 1),
#  'drawback': (0, 1),
#  'conception': (0, 0),
#  'previously': (0, 0),
#  'sponge': (0, 1),
#  'inlet': (0, 0),
#  'prayer': (0, 0),
#  'heavily': (0, 1),
#  'tail': (0, 0),
#  'station': (0, 0),
#  'flipper': (0, 0),
#  'sound': (0, 0),
#  'conservatism': (0, 0),
#  'territory': (0, 0),
#  'wear': (0, 0),
#  'primates': (0, 0),
#  'green': (0, 1),
#  'disturbance': (0, 0),
#  'hold': (0, 0),
#  'march': (0, 0),
#  'grandeur': (0, 1),
#  'fume': (0, 1),
#  'peculiarly': (0, 0),
#  'crave': (1, 0),
#  'stem': (0, 0),
#  'confine': (0, 0),
#  'crew': (0, 0),
#  'tender': (1, 1),
#  'deny': (0, 0),
#  'preservation': (0, 0),
#  'soldering': (0, 0),
#  'crook': (0, 0),
#  'entreat': (0, 0),
#  'percussion': (0, 0),
#  'hour': (0, 0),
#  'polymorphism': (0, 0),
#  'complicated': (0, 1),
#  'ley': (0, 0),
#  'bud': (0, 0),
#  'affront': (0, 0),
#  'wealth': (0, 0),
#  'admiralty': (0, 0),
#  'croak': (0, 0),
#  'crowd': (0, 0),
#  'morphism': (0, 0),
#  'betting': (0, 0),
#  'spread': (0, 0),
#  'polish': (0, 1),
#  'analysis': (0, 0),
#  'lin': (0, 0),
#  'preserved': (0, 0),
#  'rapture': (1, 1),
#  'cruelly': (2, 1),
#  'curriculum': (0, 0),
#  'council': (0, 0),
#  'sullen': (0, 0),
#  'meet': (0, 0),
#  'angiography': (0, 0),
#  'indivisible': (0, 0),
#  'lost': (1, 1),
#  'rosette': (0, 0),
#  'divert': (0, 0),
#  'introspective': (0, 0),
#  'disguise': (0, 0),
#  'fleet': (0, 0),
#  'revert': (0, 0),
#  'splendid': (1, 1),
#  'bonds': (0, 1),
#  'dismemberment': (3, 1),
#  'scrapie': (3, 1),
#  'fringe': (0, 0),
#  'charcoal': (0, 0),
#  'uninteresting': (1, 1),
#  'flight': (0, 0),
#  'accused': (0, 1),
#  'access': (0, 0),
#  'fury': (1, 1),
#  'front': (0, 0),
#  'restored': (1, 0),
#  'crunch': (0, 0),
#  'disprove': (0, 0),
#  'satellite': (0, 0),
#  'cat': (0, 0),
#  'elbow': (0, 0),
#  'nose': (0, 0),
#  'alibi': (0, 0),
#  'breakfast': (0, 0),
#  'passage': (0, 0),
#  'collie': (0, 0),
#  'calculation': (0, 0),
#  'rod': (0, 0),
#  'blowout': (0, 1),
#  'pinion': (1, 1),
#  'babbling': (0, 1),
#  'emission': (1, 0),
#  'repeat': (0, 0),
#  'accrue': (0, 0),
#  'practical': (0, 0),
#  'conjugate': (0, 0),
#  'annihilated': (3, 1),
#  'coinciding': (0, 0),
#  'superior': (1, 1),
#  'moods': (0, 0),
#  'baggy': (0, 0),
#  'stretch': (0, 0),
#  'unbroken': (0, 0),
#  'tongue': (0, 0),
#  'poke': (1, 1),
#  'difficulty': (0, 0),
#  'contractile': (0, 0),
#  'engrave': (0, 0),
#  'worthless': (0, 0),
#  'dilution': (1, 0),
#  'swear': (1, 1),
#  'boston': (0, 0),
#  'invincible': (0, 0),
#  'cloud': (0, 0),
#  'end': (0, 0),
#  'warehouse': (0, 0),
#  'unchanged': (0, 0),
#  'diffuse': (0, 0),
#  'predispose': (0, 0),
#  'absence': (0, 1),
#  'lark': (0, 0),
#  'sack': (0, 0),
#  'decline': (0, 1),
#  'displaced': (3, 0),
#  'garish': (0, 1),
#  'crammed': (0, 0),
#  'superiority': (0, 1),
#  'coincide': (0, 0),
#  'fanning': (0, 0),
#  'ticket': (0, 0),
#  'junta': (0, 0),
#  'retrospectively': (0, 0),
#  'instant': (0, 0),
#  'removal': (0, 0),
#  'cynic': (0, 0),
#  'unopposed': (1, 0),
#  'smother': (0, 0),
#  'dike': (1, 0),
#  'choke': (0, 1),
#  'confirm': (0, 0),
#  'chairman': (1, 1),
#  'role': (0, 0),
#  'warranted': (0, 0),
#  'special': (1, 1),
#  'whit': (0, 0),
#  'persistence': (0, 1),
#  'referendum': (0, 0),
#  'page': (0, 0),
#  'conflict': (2, 1),
#  'minister': (0, 0),
#  'ambiguity': (0, 0),
#  'tackling': (0, 0),
#  'diminish': (0, 0),
#  'ampersand': (0, 0),
#  'sperm': (0, 0),
#  'eventual': (1, 0),
#  'litter': (0, 0),
#  'patent': (0, 0),
#  'plump': (1, 0),
#  'hyacinth': (1, 0),
#  'mother': (0, 0),
#  'facsimile': (0, 0),
#  'covert': (0, 0),
#  'dissent': (0, 0),
#  'precocious': (0, 0),
#  'emulate': (0, 0),
#  'turf': (0, 0),
#  'harness': (0, 0),
#  'instill': (0, 0),
#  'uniformity': (0, 0),
#  'childbirth': (0, 0),
#  'skewed': (2, 1),
#  'storming': (1, 0),
#  'compile': (0, 0),
#  'unpublished': (2, 1),
#  'type': (0, 0),
#  'eccentric': (0, 0),
#  'chords': (0, 0),
#  'imperfection': (0, 1),
#  'claws': (0, 0),
#  'pervert': (0, 1),
#  'construction': (0, 0),
#  'corrupting': (4, 1),
#  'corse': (1, 0),
#  'extinct': (0, 1),
#  'fetch': (0, 0),
#  'reinvestment': (0, 0),
#  'scrambling': (0, 1),
#  'cargo': (0, 0),
#  'amphitheater': (0, 0),
#  'multiply': (0, 0),
#  'cross': (0, 0),
#  'dictate': (0, 0),
#  'morn': (1, 0),
#  'effectuate': (0, 0),
#  'admit': (0, 0),
#  'evangelist': (0, 0),
#  'union': (0, 0),
#  'scope': (0, 0),
#  'fly': (0, 0),
#  'mill': (0, 0),
#  'stick': (0, 0),
#  'mimicry': (0, 1),
#  'consecration': (1, 1),
#  'drifted': (1, 0),
#  'thrush': (0, 0),
#  'evil': (0, 0),
#  'quiver': (1, 1),
#  'vacuolar': (0, 0),
#  'acetic': (0, 0),
#  'anatomy': (0, 0),
#  'moored': (0, 0),
#  'penance': (1, 0),
#  'alumnus': (0, 0),
#  'embrace': (3, 1),
#  'doldrums': (1, 1),
#  'nanometer': (0, 0),
#  'prick': (0, 0),
#  'ecclesiastical': (0, 0),
#  'intimately': (2, 0),
#  'heroine': (1, 1),
#  'dot': (0, 0),
#  'fall': (0, 1),
#  'floor': (0, 0),
#  'rejected': (0, 1),
#  'womanhood': (0, 0),
#  'sting': (1, 1),
#  'meander': (0, 0),
#  'raptors': (1, 1),
#  'seared': (0, 0),
#  'soil': (0, 0),
#  'salvation': (0, 0),
#  'tickle': (3, 1),
#  'contingent': (0, 0),
#  'skepticism': (0, 0),
#  'dependant': (0, 0),
#  'raised': (0, 0),
#  'cosmetic': (0, 0),
#  'accidentally': (1, 0),
#  'shorn': (0, 0),
#  'casein': (0, 0),
#  'beetle': (0, 0),
#  'stubble': (0, 0),
#  'diver': (0, 0),
#  'deficiency': (0, 1),
#  'ancestral': (1, 0),
#  'peer': (0, 0),
#  'passivity': (0, 1),
#  'venomous': (0, 0),
#  'sight': (0, 0),
#  'conjecture': (0, 0),
#  'conventional': (0, 0),
#  'bothering': (2, 1),
#  'pudding': (0, 0),
#  'divide': (0, 0),
#  'curse': (4, 1),
#  'register': (0, 0),
#  'drastic': (0, 0),
#  'modification': (0, 0),
#  'bolt': (0, 0),
#  'stain': (0, 1),
#  'meow': (0, 0),
#  'broken': (2, 1),
#  'surrendering': (1, 1),
#  'poorly': (0, 1),
#  'received': (0, 0),
#  'stop': (0, 0),
#  'outlaw': (0, 1),
#  'crushing': (3, 1),
#  'trophy': (0, 1),
#  'opposition': (0, 1),
#  'cigarette': (0, 1),
#  'plate': (0, 0),
#  'outcry': (0, 0),
#  'exceed': (0, 0),
#  'riverbank': (0, 0),
#  'jargon': (0, 0),
#  'hourly': (0, 0),
#  'folklore': (0, 0),
#  'mediocrity': (1, 0),
#  'shoddy': (0, 0),
#  'puts': (0, 0),
#  'ruffle': (0, 1),
#  'suffix': (0, 0),
#  'assembled': (0, 0),
#  'warrants': (0, 0),
#  'dominion': (2, 0),
#  'dextrose': (0, 0),
#  'fan': (0, 0),
#  'temperament': (0, 0),
#  'state': (0, 0),
#  'citation': (0, 0),
#  'cheque': (0, 0),
#  'tapering': (0, 0),
#  'settle': (0, 0),
#  'supposing': (0, 0),
#  'rooted': (0, 0),
#  'solidity': (0, 0),
#  'bigot': (0, 0),
#  'brawl': (0, 0),
#  'flapping': (0, 0),
#  'solvency': (0, 1),
#  'ailment': (0, 0),
#  'sensuality': (1, 1),
#  'sacrifices': (3, 1),
#  'dainty': (0, 0),
#  'forgery': (0, 0),
#  'ward': (0, 0),
#  'quality': (0, 0),
#  'thesis': (0, 0),
#  'fry': (0, 0),
#  'endeavor': (1, 1),
#  'multiplied': (0, 0),
#  'arms': (0, 0),
#  'theory': (0, 0),
#  'constraint': (0, 0),
#  'safe': (0, 0),
#  'wrangler': (0, 0),
#  'deceased': (1, 1),
#  'photogenic': (0, 0),
#  'summarize': (0, 0),
#  'amount': (0, 0),
#  'fortnightly': (0, 0),
#  'philosophic': (0, 0),
#  'anointing': (0, 0),
#  'drenched': (0, 0),
#  'substituted': (1, 0),
#  'popularized': (0, 1),
#  'parallelism': (0, 0),
#  'footbridge': (0, 0),
#  'movie': (0, 0),
#  'helplessness': (2, 1),
#  'eld': (0, 0),
#  'revolution': (1, 1),
#  'stagger': (1, 0),
#  'snuff': (0, 0),
#  'extricate': (0, 0),
#  'project': (0, 0),
#  'obliterated': (2, 1),
#  'high': (0, 0),
#  'cussed': (1, 0),
#  'senate': (1, 0),
#  'medium': (0, 0),
#  'prose': (0, 0),
#  'localization': (0, 0),
#  'afflicted': (0, 1),
#  'sisterhood': (0, 0),
#  'frolic': (0, 1),
#  'spectacle': (0, 0),
#  'telescopic': (0, 0),
#  'differential': (0, 0),
#  'elimination': (0, 0),
#  'precedent': (0, 0),
#  'marry': (1, 0),
#  'changed': (0, 0),
#  'foliage': (0, 0),
#  'atom': (0, 1),
#  'desperate': (0, 1),
#  'smack': (1, 1),
#  'penetrate': (0, 0),
#  'parlor': (0, 0),
#  'immunity': (0, 0),
#  'task': (0, 1),
#  'advisable': (1, 1),
#  'dismiss': (0, 0),
#  'psychics': (0, 0),
#  'tower': (0, 0),
#  'redress': (0, 0),
#  'mold': (0, 0),
#  'trustee': (1, 0),
#  'impracticable': (0, 0),
#  'deviate': (0, 0),
#  'amid': (0, 0),
#  'racket': (0, 0),
#  'sore': (2, 1),
#  'depression': (0, 0),
#  'rescue': (0, 0),
#  'blush': (0, 0),
#  'despatch': (0, 0),
#  'naked': (0, 0),
#  'tract': (0, 0),
#  'conviction': (0, 0),
#  'dashboard': (0, 0),
#  'tern': (0, 0),
#  'whet': (0, 0),
#  'stole': (0, 0),
#  'kindness': (0, 1),
#  'unbiased': (0, 1),
#  'innocent': (0, 1),
#  'perturbation': (0, 0),
#  'thrift': (0, 0),
#  'hanging': (0, 0),
#  'comprise': (0, 0),
#  'squamous': (0, 0),
#  'fraction': (0, 0),
#  'oil': (0, 0),
#  'shattered': (0, 1),
#  'fetish': (0, 0),
#  'curate': (0, 0),
#  'baccarat': (0, 0),
#  'stuff': (0, 0),
#  'volunteer': (0, 0),
#  'yield': (0, 0),
#  'caricature': (0, 1),
#  'neurotic': (2, 1),
#  'uncommonly': (0, 0),
#  'indefensible': (0, 0),
#  'voucher': (0, 0),
#  'pungent': (1, 1),
#  'steep': (0, 0),
#  'doubt': (0, 0),
#  'semen': (0, 0),
#  'acme': (0, 0),
#  'merciless': (1, 1),
#  'cytoplasm': (0, 0),
#  'pluck': (0, 0),
#  'dash': (0, 0),
#  'communication': (0, 0),
#  'limit': (0, 0),
#  'elude': (0, 0),
#  'expatriate': (0, 1),
#  ...}

# %%
len(senseScore)
# Out:
# 4819

# %%
senseScore
# Out:
# {'paraphrase': (0, 0),
#  'porosity': (0, 0),
#  'invaluable': (0, 0),
#  'virulence': (2, 1),
#  'complexity': (0, 1),
#  'chapter': (0, 0),
#  'untranslated': (0, 0),
#  'swell': (0, 0),
#  'presumption': (1, 0),
#  'hood': (0, 0),
#  'tolerate': (2, 1),
#  'prove': (0, 1),
#  'saving': (0, 0),
#  'aggressor': (2, 1),
#  'theism': (1, 1),
#  'sphere': (0, 0),
#  'delayed': (0, 1),
#  'backfire': (0, 0),
#  'curtain': (0, 0),
#  'weird': (0, 0),
#  'innovate': (0, 1),
#  'act': (0, 0),
#  'resort': (0, 0),
#  'void': (0, 0),
#  'disregarded': (1, 1),
#  'fair': (0, 1),
#  'press': (0, 0),
#  'pronounce': (0, 0),
#  'hate': (3, 1),
#  'gob': (1, 0),
#  'horticultural': (0, 0),
#  'organization': (0, 1),
#  'foolish': (0, 0),
#  'vegetarianism': (0, 0),
#  'association': (0, 0),
#  'phony': (0, 1),
#  'port': (0, 0),
#  'vista': (0, 0),
#  'dermatology': (0, 0),
#  'tribulation': (2, 1),
#  'spill': (0, 0),
#  'sway': (0, 0),
#  'failing': (3, 1),
#  'economics': (0, 0),
#  'gills': (0, 0),
#  'politics': (0, 0),
#  'forearm': (2, 0),
#  'overtaken': (0, 0),
#  'estuary': (0, 0),
#  'homosexuality': (0, 1),
#  'flickering': (0, 0),
#  'meshes': (0, 0),
#  'toby': (0, 0),
#  'flurry': (0, 0),
#  'butt': (0, 1),
#  'commence': (0, 0),
#  'usual': (1, 0),
#  'favor': (0, 0),
#  'relief': (0, 1),
#  'perform': (0, 0),
#  'unimproved': (0, 1),
#  'academy': (0, 1),
#  'brooding': (0, 0),
#  'fell': (1, 1),
#  'tag': (0, 0),
#  'susceptibility': (1, 0),
#  'untoward': (1, 1),
#  'conjunction': (0, 0),
#  'dictatorial': (1, 1),
#  'monster': (1, 1),
#  'sturdy': (0, 1),
#  'variations': (0, 0),
#  'sib': (1, 0),
#  'cooling': (0, 0),
#  'offered': (0, 0),
#  'taste': (0, 0),
#  'dam': (0, 0),
#  'danger': (2, 1),
#  'wind': (0, 0),
#  'anaconda': (2, 1),
#  'apologize': (0, 0),
#  'opiate': (0, 1),
#  'fill': (1, 0),
#  'speculative': (0, 0),
#  'size': (0, 0),
#  'erratum': (1, 1),
#  'warrant': (0, 0),
#  'conscientious': (1, 1),
#  'enamel': (0, 0),
#  'patience': (0, 0),
#  'tropical': (0, 0),
#  'paint': (0, 0),
#  'seasoning': (0, 0),
#  'exile': (0, 0),
#  'roll': (0, 0),
#  'strengthening': (1, 1),
#  'dormitory': (0, 0),
#  'rise': (0, 0),
#  'willow': (0, 0),
#  'tripping': (0, 0),
#  'compass': (1, 0),
#  'rap': (0, 0),
#  'benzene': (0, 0),
#  'bookstore': (0, 0),
#  'lymphatic': (0, 0),
#  'inspiration': (0, 0),
#  'jimmy': (0, 0),
#  'infraction': (0, 0),
#  'cobble': (0, 0),
#  'overture': (0, 0),
#  'gauging': (1, 0),
#  'staccato': (0, 1),
#  'dyke': (0, 0),
#  'birthplace': (1, 1),
#  'separation': (0, 0),
#  'lending': (0, 0),
#  'familiarity': (0, 0),
#  'ancient': (0, 1),
#  'presentable': (0, 1),
#  'distortion': (0, 1),
#  'libido': (0, 0),
#  'advise': (1, 1),
#  'milligram': (0, 0),
#  'civic': (0, 0),
#  'uncover': (1, 0),
#  'ghost': (1, 0),
#  'romp': (0, 1),
#  'parallax': (0, 0),
#  'object': (0, 0),
#  'broadcast': (0, 0),
#  'instrumental': (0, 0),
#  'jack': (0, 0),
#  'revise': (0, 0),
#  'minivan': (0, 0),
#  'fasting': (1, 0),
#  'company': (0, 0),
#  'saloon': (0, 0),
#  'shockingly': (1, 0),
#  'dogged': (0, 1),
#  'weakened': (0, 1),
#  'recognizable': (0, 1),
#  'wedge': (0, 0),
#  'agency': (0, 0),
#  'acquiring': (1, 1),
#  'prestige': (0, 0),
#  'doit': (0, 1),
#  'reorganize': (0, 0),
#  'contentious': (0, 0),
#  'outrageous': (0, 0),
#  'sum': (0, 0),
#  'eavesdropping': (0, 1),
#  'treat': (0, 1),
#  'sour': (0, 1),
#  'droll': (0, 0),
#  'kos': (0, 0),
#  'apportionment': (0, 0),
#  'subvert': (0, 0),
#  'etiology': (0, 0),
#  'behavior': (0, 0),
#  'adjunct': (0, 0),
#  'unimaginable': (0, 0),
#  'planting': (0, 0),
#  'punctual': (0, 0),
#  'words': (1, 1),
#  'oppressive': (0, 0),
#  'mobilization': (0, 0),
#  'honeycomb': (0, 0),
#  'undo': (0, 1),
#  'fossils': (0, 0),
#  'slates': (0, 0),
#  'descendant': (0, 0),
#  'admiration': (0, 0),
#  'make': (0, 0),
#  'cyanide': (1, 1),
#  'vanish': (0, 0),
#  'impression': (0, 1),
#  'rail': (0, 0),
#  'slaughtering': (5, 1),
#  'unorganized': (0, 0),
#  'materials': (0, 0),
#  'urge': (0, 0),
#  'pool': (0, 0),
#  'permanence': (0, 0),
#  'organism': (0, 0),
#  'eve': (0, 0),
#  'swinging': (0, 0),
#  'regular': (0, 0),
#  'bearing': (0, 0),
#  'friend': (0, 0),
#  'inspire': (0, 0),
#  'reactionary': (0, 0),
#  'fiduciary': (0, 0),
#  'pay': (0, 0),
#  'rarity': (0, 0),
#  'aimless': (0, 0),
#  'humanities': (0, 0),
#  'interruption': (0, 0),
#  'itching': (0, 0),
#  'liabilities': (0, 0),
#  'dreaming': (0, 0),
#  'scaffold': (0, 0),
#  'pavilion': (0, 0),
#  'poignant': (0, 0),
#  'blower': (0, 1),
#  'vindicated': (0, 1),
#  'disorder': (0, 0),
#  'idiot': (1, 1),
#  'scout': (0, 0),
#  'multiplication': (0, 0),
#  'single': (0, 0),
#  'methanol': (0, 1),
#  'dodging': (0, 0),
#  'moronic': (0, 1),
#  'lumbar': (0, 0),
#  'advance': (0, 1),
#  'elaborate': (0, 0),
#  'constitutionality': (0, 0),
#  'aberrant': (0, 0),
#  'hug': (1, 1),
#  'ingot': (0, 0),
#  'column': (0, 0),
#  'farce': (0, 1),
#  'bang': (5, 1),
#  'tablet': (0, 0),
#  'scan': (0, 0),
#  'approximating': (0, 0),
#  'tat': (0, 0),
#  'unsettled': (0, 0),
#  'prowess': (0, 0),
#  'grudge': (1, 1),
#  'spatula': (0, 0),
#  'olfactory': (1, 1),
#  'cumbersome': (1, 1),
#  'crack': (0, 0),
#  'reassuring': (0, 0),
#  'pause': (1, 0),
#  'refuse': (0, 1),
#  'residences': (0, 0),
#  'accomplice': (1, 0),
#  'salty': (0, 0),
#  'stone': (0, 0),
#  'addressee': (0, 0),
#  'pump': (0, 0),
#  'vanished': (3, 1),
#  'director': (0, 0),
#  'notation': (0, 0),
#  'rubbish': (1, 1),
#  'jerk': (2, 0),
#  'centralize': (1, 0),
#  'resign': (0, 0),
#  'element': (0, 0),
#  'untrue': (0, 0),
#  'pundit': (0, 0),
#  'transformation': (0, 0),
#  'maneuvering': (0, 0),
#  'unacceptable': (1, 1),
#  'dock': (0, 0),
#  'firm': (0, 0),
#  'collect': (1, 0),
#  'blighted': (2, 1),
#  'succession': (0, 0),
#  'nib': (0, 0),
#  'roughness': (0, 1),
#  'circulation': (0, 0),
#  'construct': (0, 1),
#  'disgust': (0, 0),
#  'dwarfed': (2, 1),
#  'admixture': (0, 0),
#  'catholic': (0, 0),
#  'breech': (0, 0),
#  'enema': (1, 0),
#  'impotence': (2, 1),
#  'desperation': (0, 0),
#  'rake': (0, 0),
#  'depository': (1, 0),
#  'probe': (0, 0),
#  'grieve': (0, 0),
#  'receipts': (0, 0),
#  'harmony': (0, 1),
#  'express': (0, 0),
#  'induced': (0, 0),
#  'dime': (0, 0),
#  'moderate': (0, 0),
#  'parenchyma': (0, 0),
#  'fascination': (0, 0),
#  'forecast': (0, 0),
#  'speedway': (0, 0),
#  'donor': (1, 0),
#  'townhouse': (0, 0),
#  'cutting': (4, 1),
#  'rout': (0, 1),
#  'riot': (2, 1),
#  'endowed': (0, 1),
#  'outbreak': (0, 0),
#  'dog': (0, 0),
#  'shire': (0, 0),
#  'compost': (1, 1),
#  'digest': (0, 0),
#  'jubilee': (0, 0),
#  'standoff': (2, 1),
#  'club': (0, 0),
#  'walk': (0, 0),
#  'bitterly': (3, 1),
#  'soc': (0, 0),
#  'main': (0, 0),
#  'completion': (0, 0),
#  'ken': (0, 1),
#  'remarkably': (0, 1),
#  'figure': (0, 0),
#  'spy': (0, 0),
#  'refusing': (0, 0),
#  'darn': (0, 0),
#  'judge': (0, 0),
#  'moldy': (0, 0),
#  'disparage': (0, 0),
#  'sentinel': (0, 0),
#  'attacking': (5, 1),
#  'image': (0, 0),
#  'halting': (2, 1),
#  'pickle': (0, 1),
#  'surroundings': (0, 0),
#  'energy': (0, 0),
#  'revisit': (0, 0),
#  'pregnancy': (1, 1),
#  'fraternal': (0, 0),
#  'cooperation': (0, 1),
#  'modesty': (0, 1),
#  'slide': (0, 0),
#  'gossip': (0, 0),
#  'strive': (1, 0),
#  'toothless': (0, 0),
#  'stripe': (0, 0),
#  'bull': (0, 0),
#  'household': (0, 0),
#  'visor': (3, 0),
#  'crash': (0, 0),
#  'presence': (0, 0),
#  'producing': (0, 1),
#  'serpent': (2, 1),
#  'grain': (0, 0),
#  'retiring': (1, 0),
#  'publication': (0, 0),
#  'conic': (0, 0),
#  'haunt': (1, 1),
#  'semblance': (0, 0),
#  'hiss': (0, 0),
#  'illustrate': (0, 0),
#  'readiness': (2, 1),
#  'equivalent': (0, 0),
#  'denied': (2, 1),
#  'corner': (0, 0),
#  'stamina': (0, 0),
#  'mir': (0, 0),
#  'dementia': (2, 1),
#  'theater': (0, 0),
#  'palpable': (0, 0),
#  'dispersion': (0, 0),
#  'ovary': (0, 0),
#  'decoration': (1, 0),
#  'pretending': (1, 1),
#  'courtesy': (0, 0),
#  'incompetence': (0, 0),
#  'jaguar': (0, 0),
#  'raise': (0, 0),
#  'assumption': (0, 0),
#  'fitness': (0, 0),
#  'carve': (0, 0),
#  'handy': (0, 0),
#  'bag': (0, 0),
#  'soaking': (0, 0),
#  'recombinant': (0, 0),
#  'innocuous': (0, 0),
#  'fenced': (1, 0),
#  'studded': (0, 0),
#  'marshal': (0, 0),
#  'plain': (0, 0),
#  'resisting': (0, 0),
#  'angel': (3, 1),
#  'coexistence': (0, 0),
#  'grant': (2, 1),
#  'pen': (0, 0),
#  'tritium': (0, 0),
#  'parquet': (1, 0),
#  'demonstrated': (0, 0),
#  'nervous': (0, 0),
#  'dew': (0, 0),
#  'flashing': (0, 0),
#  'dissertation': (0, 0),
#  'cry': (0, 0),
#  'embryo': (0, 0),
#  'succeed': (1, 0),
#  'acknowledged': (0, 0),
#  'immaterial': (0, 0),
#  'dawn': (3, 1),
#  'fret': (1, 1),
#  'institution': (0, 0),
#  'efficient': (0, 0),
#  'marble': (0, 0),
#  'courses': (0, 0),
#  'study': (0, 1),
#  'unsatisfied': (1, 0),
#  'cut': (0, 0),
#  'flaw': (0, 1),
#  'flanked': (0, 0),
#  'plowed': (0, 0),
#  'concealment': (2, 1),
#  'rack': (1, 1),
#  'potter': (0, 0),
#  'enforcement': (0, 1),
#  'luxuriant': (0, 1),
#  'engrossed': (0, 0),
#  'plush': (0, 1),
#  'adequate': (0, 0),
#  'puma': (2, 0),
#  'word': (0, 0),
#  'disagreeing': (0, 1),
#  'intelligence': (0, 0),
#  'shell': (0, 0),
#  'analyzer': (0, 0),
#  'commodity': (0, 0),
#  'doublet': (1, 0),
#  'guide': (1, 1),
#  'facts': (1, 1),
#  'horrible': (0, 0),
#  'undermined': (0, 1),
#  'tipsy': (0, 1),
#  'suspense': (0, 0),
#  'pending': (0, 0),
#  'bask': (0, 0),
#  'conciliation': (0, 1),
#  'tenderness': (0, 1),
#  'incentive': (0, 0),
#  'marked': (0, 0),
#  'fecal': (1, 1),
#  'overlying': (0, 0),
#  'row': (1, 1),
#  'cipher': (0, 0),
#  'assimilate': (0, 0),
#  'heat': (0, 0),
#  'conditionally': (0, 0),
#  'welcomed': (0, 1),
#  'arbor': (0, 0),
#  'emotion': (0, 0),
#  'devolve': (0, 0),
#  'vertebral': (0, 0),
#  'fudge': (0, 1),
#  'unauthorized': (0, 0),
#  'instruct': (0, 0),
#  'introductory': (0, 0),
#  'recursively': (0, 0),
#  'vertigo': (1, 0),
#  'barrel': (0, 0),
#  'immaturity': (1, 1),
#  'aby': (0, 0),
#  'purchase': (0, 0),
#  'mineral': (0, 0),
#  'herald': (0, 0),
#  'punctuality': (0, 1),
#  'sphinx': (0, 0),
#  'damsel': (0, 0),
#  'armor': (2, 1),
#  'law': (1, 0),
#  'bomb': (0, 0),
#  'superimposed': (0, 0),
#  'squirrel': (0, 0),
#  'partisan': (0, 0),
#  'gallery': (0, 0),
#  'carry': (0, 0),
#  'geranium': (0, 1),
#  'fake': (0, 0),
#  'allowance': (0, 0),
#  'scale': (0, 0),
#  'dummy': (0, 1),
#  'overlay': (0, 0),
#  'inconsiderate': (0, 0),
#  'boot': (0, 0),
#  'toxicology': (0, 0),
#  'royal': (0, 0),
#  'cumulus': (0, 0),
#  'defined': (0, 0),
#  'restriction': (0, 0),
#  'burnout': (1, 0),
#  'eclipse': (0, 0),
#  'rope': (0, 0),
#  'letter': (0, 0),
#  'stationary': (0, 0),
#  'blunder': (0, 0),
#  'line': (0, 0),
#  'delineate': (0, 0),
#  'peridot': (0, 0),
#  'languish': (0, 1),
#  'porch': (0, 0),
#  'possess': (1, 0),
#  'wit': (0, 1),
#  'ovation': (1, 1),
#  'jackass': (0, 0),
#  'happy': (0, 1),
#  'overlaid': (0, 0),
#  'link': (0, 0),
#  'rawhide': (0, 0),
#  'insulate': (0, 0),
#  'impossible': (1, 1),
#  'venous': (0, 0),
#  'field': (0, 0),
#  'kudos': (0, 1),
#  'sparring': (0, 0),
#  'order': (0, 0),
#  'quote': (2, 1),
#  'limp': (0, 0),
#  'centrality': (0, 0),
#  'affliction': (0, 0),
#  'product': (0, 0),
#  'irregularity': (0, 0),
#  'blot': (0, 1),
#  'spit': (0, 0),
#  'silly': (0, 0),
#  'approach': (0, 0),
#  'charter': (0, 0),
#  'repository': (0, 0),
#  'float': (0, 0),
#  'rust': (0, 0),
#  'comprehend': (0, 0),
#  'confuse': (1, 1),
#  'reinforcement': (0, 0),
#  'cultivation': (0, 0),
#  'clutches': (0, 0),
#  'appliances': (0, 0),
#  'creation': (0, 0),
#  'environment': (0, 0),
#  'adieu': (0, 0),
#  'memorials': (1, 0),
#  'dolphin': (2, 1),
#  'kink': (0, 0),
#  'atlas': (0, 0),
#  'rollers': (0, 0),
#  'snarling': (1, 1),
#  'recesses': (1, 0),
#  'laboring': (0, 0),
#  'distress': (0, 0),
#  'unclaimed': (0, 0),
#  'ready': (1, 0),
#  'defiance': (0, 0),
#  'stays': (0, 0),
#  'cinch': (0, 0),
#  'hinge': (0, 0),
#  'radically': (0, 0),
#  'frequent': (0, 0),
#  'godly': (1, 1),
#  'recruiting': (0, 0),
#  'flatness': (1, 0),
#  'encrypt': (0, 0),
#  'pegs': (0, 0),
#  'cereal': (0, 0),
#  'indelible': (0, 0),
#  'preside': (0, 0),
#  'extant': (0, 0),
#  'monarchy': (0, 0),
#  'journal': (0, 0),
#  'herbarium': (0, 0),
#  'antibiotics': (0, 1),
#  'continuously': (0, 0),
#  'prod': (0, 0),
#  'uninfected': (0, 1),
#  'irritation': (3, 1),
#  'uncertainty': (2, 1),
#  'adjustment': (0, 0),
#  'concern': (0, 0),
#  'prog': (0, 0),
#  'chore': (1, 1),
#  'infinite': (0, 0),
#  'cup': (0, 0),
#  'feather': (0, 0),
#  'fractional': (1, 0),
#  'observance': (0, 0),
#  'sustenance': (0, 0),
#  'oversight': (0, 1),
#  'discovery': (0, 1),
#  'drawback': (0, 1),
#  'conception': (0, 0),
#  'previously': (0, 0),
#  'sponge': (0, 1),
#  'inlet': (0, 0),
#  'prayer': (0, 0),
#  'heavily': (0, 1),
#  'tail': (0, 0),
#  'station': (0, 0),
#  'flipper': (0, 0),
#  'sound': (0, 0),
#  'conservatism': (0, 0),
#  'territory': (0, 0),
#  'wear': (0, 0),
#  'primates': (0, 0),
#  'green': (0, 1),
#  'disturbance': (0, 0),
#  'hold': (0, 0),
#  'march': (0, 0),
#  'grandeur': (0, 1),
#  'fume': (0, 1),
#  'peculiarly': (0, 0),
#  'crave': (1, 0),
#  'stem': (0, 0),
#  'confine': (0, 0),
#  'crew': (0, 0),
#  'tender': (1, 1),
#  'deny': (0, 0),
#  'preservation': (0, 0),
#  'soldering': (0, 0),
#  'crook': (0, 0),
#  'entreat': (0, 0),
#  'percussion': (0, 0),
#  'hour': (0, 0),
#  'polymorphism': (0, 0),
#  'complicated': (0, 1),
#  'ley': (0, 0),
#  'bud': (0, 0),
#  'affront': (0, 0),
#  'wealth': (0, 0),
#  'admiralty': (0, 0),
#  'croak': (0, 0),
#  'crowd': (0, 0),
#  'morphism': (0, 0),
#  'betting': (0, 0),
#  'spread': (0, 0),
#  'polish': (0, 1),
#  'analysis': (0, 0),
#  'lin': (0, 0),
#  'preserved': (0, 0),
#  'rapture': (1, 1),
#  'cruelly': (2, 1),
#  'curriculum': (0, 0),
#  'council': (0, 0),
#  'sullen': (0, 0),
#  'meet': (0, 0),
#  'angiography': (0, 0),
#  'indivisible': (0, 0),
#  'lost': (1, 1),
#  'rosette': (0, 0),
#  'divert': (0, 0),
#  'introspective': (0, 0),
#  'disguise': (0, 0),
#  'fleet': (0, 0),
#  'revert': (0, 0),
#  'splendid': (1, 1),
#  'bonds': (0, 1),
#  'dismemberment': (3, 1),
#  'scrapie': (3, 1),
#  'fringe': (0, 0),
#  'charcoal': (0, 0),
#  'uninteresting': (1, 1),
#  'flight': (0, 0),
#  'accused': (0, 1),
#  'access': (0, 0),
#  'fury': (1, 1),
#  'front': (0, 0),
#  'restored': (1, 0),
#  'crunch': (0, 0),
#  'disprove': (0, 0),
#  'satellite': (0, 0),
#  'cat': (0, 0),
#  'elbow': (0, 0),
#  'nose': (0, 0),
#  'alibi': (0, 0),
#  'breakfast': (0, 0),
#  'passage': (0, 0),
#  'collie': (0, 0),
#  'calculation': (0, 0),
#  'rod': (0, 0),
#  'blowout': (0, 1),
#  'pinion': (1, 1),
#  'babbling': (0, 1),
#  'emission': (1, 0),
#  'repeat': (0, 0),
#  'accrue': (0, 0),
#  'practical': (0, 0),
#  'conjugate': (0, 0),
#  'annihilated': (3, 1),
#  'coinciding': (0, 0),
#  'superior': (1, 1),
#  'moods': (0, 0),
#  'baggy': (0, 0),
#  'stretch': (0, 0),
#  'unbroken': (0, 0),
#  'tongue': (0, 0),
#  'poke': (1, 1),
#  'difficulty': (0, 0),
#  'contractile': (0, 0),
#  'engrave': (0, 0),
#  'worthless': (0, 0),
#  'dilution': (1, 0),
#  'swear': (1, 1),
#  'boston': (0, 0),
#  'invincible': (0, 0),
#  'cloud': (0, 0),
#  'end': (0, 0),
#  'warehouse': (0, 0),
#  'unchanged': (0, 0),
#  'diffuse': (0, 0),
#  'predispose': (0, 0),
#  'absence': (0, 1),
#  'lark': (0, 0),
#  'sack': (0, 0),
#  'decline': (0, 1),
#  'displaced': (3, 0),
#  'garish': (0, 1),
#  'crammed': (0, 0),
#  'superiority': (0, 1),
#  'coincide': (0, 0),
#  'fanning': (0, 0),
#  'ticket': (0, 0),
#  'junta': (0, 0),
#  'retrospectively': (0, 0),
#  'instant': (0, 0),
#  'removal': (0, 0),
#  'cynic': (0, 0),
#  'unopposed': (1, 0),
#  'smother': (0, 0),
#  'dike': (1, 0),
#  'choke': (0, 1),
#  'confirm': (0, 0),
#  'chairman': (1, 1),
#  'role': (0, 0),
#  'warranted': (0, 0),
#  'special': (1, 1),
#  'whit': (0, 0),
#  'persistence': (0, 1),
#  'referendum': (0, 0),
#  'page': (0, 0),
#  'conflict': (2, 1),
#  'minister': (0, 0),
#  'ambiguity': (0, 0),
#  'tackling': (0, 0),
#  'diminish': (0, 0),
#  'ampersand': (0, 0),
#  'sperm': (0, 0),
#  'eventual': (1, 0),
#  'litter': (0, 0),
#  'patent': (0, 0),
#  'plump': (1, 0),
#  'hyacinth': (1, 0),
#  'mother': (0, 0),
#  'facsimile': (0, 0),
#  'covert': (0, 0),
#  'dissent': (0, 0),
#  'precocious': (0, 0),
#  'emulate': (0, 0),
#  'turf': (0, 0),
#  'harness': (0, 0),
#  'instill': (0, 0),
#  'uniformity': (0, 0),
#  'childbirth': (0, 0),
#  'skewed': (2, 1),
#  'storming': (1, 0),
#  'compile': (0, 0),
#  'unpublished': (2, 1),
#  'type': (0, 0),
#  'eccentric': (0, 0),
#  'chords': (0, 0),
#  'imperfection': (0, 1),
#  'claws': (0, 0),
#  'pervert': (0, 1),
#  'construction': (0, 0),
#  'corrupting': (4, 1),
#  'corse': (1, 0),
#  'extinct': (0, 1),
#  'fetch': (0, 0),
#  'reinvestment': (0, 0),
#  'scrambling': (0, 1),
#  'cargo': (0, 0),
#  'amphitheater': (0, 0),
#  'multiply': (0, 0),
#  'cross': (0, 0),
#  'dictate': (0, 0),
#  'morn': (1, 0),
#  'effectuate': (0, 0),
#  'admit': (0, 0),
#  'evangelist': (0, 0),
#  'union': (0, 0),
#  'scope': (0, 0),
#  'fly': (0, 0),
#  'mill': (0, 0),
#  'stick': (0, 0),
#  'mimicry': (0, 1),
#  'consecration': (1, 1),
#  'drifted': (1, 0),
#  'thrush': (0, 0),
#  'evil': (0, 0),
#  'quiver': (1, 1),
#  'vacuolar': (0, 0),
#  'acetic': (0, 0),
#  'anatomy': (0, 0),
#  'moored': (0, 0),
#  'penance': (1, 0),
#  'alumnus': (0, 0),
#  'embrace': (3, 1),
#  'doldrums': (1, 1),
#  'nanometer': (0, 0),
#  'prick': (0, 0),
#  'ecclesiastical': (0, 0),
#  'intimately': (2, 0),
#  'heroine': (1, 1),
#  'dot': (0, 0),
#  'fall': (0, 1),
#  'floor': (0, 0),
#  'rejected': (0, 1),
#  'womanhood': (0, 0),
#  'sting': (1, 1),
#  'meander': (0, 0),
#  'raptors': (1, 1),
#  'seared': (0, 0),
#  'soil': (0, 0),
#  'salvation': (0, 0),
#  'tickle': (3, 1),
#  'contingent': (0, 0),
#  'skepticism': (0, 0),
#  'dependant': (0, 0),
#  'raised': (0, 0),
#  'cosmetic': (0, 0),
#  'accidentally': (1, 0),
#  'shorn': (0, 0),
#  'casein': (0, 0),
#  'beetle': (0, 0),
#  'stubble': (0, 0),
#  'diver': (0, 0),
#  'deficiency': (0, 1),
#  'ancestral': (1, 0),
#  'peer': (0, 0),
#  'passivity': (0, 1),
#  'venomous': (0, 0),
#  'sight': (0, 0),
#  'conjecture': (0, 0),
#  'conventional': (0, 0),
#  'bothering': (2, 1),
#  'pudding': (0, 0),
#  'divide': (0, 0),
#  'curse': (4, 1),
#  'register': (0, 0),
#  'drastic': (0, 0),
#  'modification': (0, 0),
#  'bolt': (0, 0),
#  'stain': (0, 1),
#  'meow': (0, 0),
#  'broken': (2, 1),
#  'surrendering': (1, 1),
#  'poorly': (0, 1),
#  'received': (0, 0),
#  'stop': (0, 0),
#  'outlaw': (0, 1),
#  'crushing': (3, 1),
#  'trophy': (0, 1),
#  'opposition': (0, 1),
#  'cigarette': (0, 1),
#  'plate': (0, 0),
#  'outcry': (0, 0),
#  'exceed': (0, 0),
#  'riverbank': (0, 0),
#  'jargon': (0, 0),
#  'hourly': (0, 0),
#  'folklore': (0, 0),
#  'mediocrity': (1, 0),
#  'shoddy': (0, 0),
#  'puts': (0, 0),
#  'ruffle': (0, 1),
#  'suffix': (0, 0),
#  'assembled': (0, 0),
#  'warrants': (0, 0),
#  'dominion': (2, 0),
#  'dextrose': (0, 0),
#  'fan': (0, 0),
#  'temperament': (0, 0),
#  'state': (0, 0),
#  'citation': (0, 0),
#  'cheque': (0, 0),
#  'tapering': (0, 0),
#  'settle': (0, 0),
#  'supposing': (0, 0),
#  'rooted': (0, 0),
#  'solidity': (0, 0),
#  'bigot': (0, 0),
#  'brawl': (0, 0),
#  'flapping': (0, 0),
#  'solvency': (0, 1),
#  'ailment': (0, 0),
#  'sensuality': (1, 1),
#  'sacrifices': (3, 1),
#  'dainty': (0, 0),
#  'forgery': (0, 0),
#  'ward': (0, 0),
#  'quality': (0, 0),
#  'thesis': (0, 0),
#  'fry': (0, 0),
#  'endeavor': (1, 1),
#  'multiplied': (0, 0),
#  'arms': (0, 0),
#  'theory': (0, 0),
#  'constraint': (0, 0),
#  'safe': (0, 0),
#  'wrangler': (0, 0),
#  'deceased': (1, 1),
#  'photogenic': (0, 0),
#  'summarize': (0, 0),
#  'amount': (0, 0),
#  'fortnightly': (0, 0),
#  'philosophic': (0, 0),
#  'anointing': (0, 0),
#  'drenched': (0, 0),
#  'substituted': (1, 0),
#  'popularized': (0, 1),
#  'parallelism': (0, 0),
#  'footbridge': (0, 0),
#  'movie': (0, 0),
#  'helplessness': (2, 1),
#  'eld': (0, 0),
#  'revolution': (1, 1),
#  'stagger': (1, 0),
#  'snuff': (0, 0),
#  'extricate': (0, 0),
#  'project': (0, 0),
#  'obliterated': (2, 1),
#  'high': (0, 0),
#  'cussed': (1, 0),
#  'senate': (1, 0),
#  'medium': (0, 0),
#  'prose': (0, 0),
#  'localization': (0, 0),
#  'afflicted': (0, 1),
#  'sisterhood': (0, 0),
#  'frolic': (0, 1),
#  'spectacle': (0, 0),
#  'telescopic': (0, 0),
#  'differential': (0, 0),
#  'elimination': (0, 0),
#  'precedent': (0, 0),
#  'marry': (1, 0),
#  'changed': (0, 0),
#  'foliage': (0, 0),
#  'atom': (0, 1),
#  'desperate': (0, 1),
#  'smack': (1, 1),
#  'penetrate': (0, 0),
#  'parlor': (0, 0),
#  'immunity': (0, 0),
#  'task': (0, 1),
#  'advisable': (1, 1),
#  'dismiss': (0, 0),
#  'psychics': (0, 0),
#  'tower': (0, 0),
#  'redress': (0, 0),
#  'mold': (0, 0),
#  'trustee': (1, 0),
#  'impracticable': (0, 0),
#  'deviate': (0, 0),
#  'amid': (0, 0),
#  'racket': (0, 0),
#  'sore': (2, 1),
#  'depression': (0, 0),
#  'rescue': (0, 0),
#  'blush': (0, 0),
#  'despatch': (0, 0),
#  'naked': (0, 0),
#  'tract': (0, 0),
#  'conviction': (0, 0),
#  'dashboard': (0, 0),
#  'tern': (0, 0),
#  'whet': (0, 0),
#  'stole': (0, 0),
#  'kindness': (0, 1),
#  'unbiased': (0, 1),
#  'innocent': (0, 1),
#  'perturbation': (0, 0),
#  'thrift': (0, 0),
#  'hanging': (0, 0),
#  'comprise': (0, 0),
#  'squamous': (0, 0),
#  'fraction': (0, 0),
#  'oil': (0, 0),
#  'shattered': (0, 1),
#  'fetish': (0, 0),
#  'curate': (0, 0),
#  'baccarat': (0, 0),
#  'stuff': (0, 0),
#  'volunteer': (0, 0),
#  'yield': (0, 0),
#  'caricature': (0, 1),
#  'neurotic': (2, 1),
#  'uncommonly': (0, 0),
#  'indefensible': (0, 0),
#  'voucher': (0, 0),
#  'pungent': (1, 1),
#  'steep': (0, 0),
#  'doubt': (0, 0),
#  'semen': (0, 0),
#  'acme': (0, 0),
#  'merciless': (1, 1),
#  'cytoplasm': (0, 0),
#  'pluck': (0, 0),
#  'dash': (0, 0),
#  'communication': (0, 0),
#  'limit': (0, 0),
#  'elude': (0, 0),
#  'expatriate': (0, 1),
#  ...}

# %%
words = filterScore(senseScore)

# %%
len(words)
# Out:
# 1172

# %%
words
# Out:
# {'receiving': (2, 1),
#  'tribute': (0, 1),
#  'revive': (0, 1),
#  'aggressor': (2, 1),
#  'complexity': (0, 1),
#  'absentee': (1, 1),
#  'providing': (0, 1),
#  'dexterity': (0, 1),
#  'staring': (0, 1),
#  'banish': (0, 1),
#  'tolerate': (2, 1),
#  'prove': (0, 1),
#  'anaconda': (2, 1),
#  'virulence': (2, 1),
#  'theism': (1, 1),
#  'heroism': (3, 1),
#  'expel': (4, 1),
#  'equilibrium': (0, 1),
#  'delayed': (0, 1),
#  'dust': (0, 1),
#  'innovate': (0, 1),
#  'champion': (2, 1),
#  'kitten': (1, 1),
#  'acquiring': (1, 1),
#  'lacking': (0, 1),
#  'prohibition': (0, 1),
#  'disregarded': (1, 1),
#  'fair': (0, 1),
#  'wot': (1, 1),
#  'refusal': (0, 1),
#  'vegetative': (2, 1),
#  'renunciation': (0, 1),
#  'graciously': (0, 1),
#  'cute': (0, 1),
#  'nutritious': (1, 1),
#  'organization': (0, 1),
#  'dispute': (1, 1),
#  'foreclose': (2, 1),
#  'expatriate': (0, 1),
#  'phony': (0, 1),
#  'acknowledgment': (0, 1),
#  'vindicated': (0, 1),
#  'minimize': (0, 1),
#  'picketing': (1, 1),
#  'tribulation': (2, 1),
#  'chivalry': (0, 1),
#  'accredited': (1, 1),
#  'excluding': (1, 1),
#  'neglecting': (0, 1),
#  'failing': (3, 1),
#  'burglary': (0, 1),
#  'explosion': (2, 1),
#  'ken': (0, 1),
#  'confidence': (2, 1),
#  'discord': (1, 1),
#  'cheer': (2, 1),
#  'substance': (0, 1),
#  'thrill': (3, 1),
#  'intelligent': (1, 1),
#  'homosexuality': (0, 1),
#  'martyrdom': (0, 1),
#  'mockery': (1, 1),
#  'elect': (0, 1),
#  'pretending': (1, 1),
#  'pick': (0, 1),
#  'butt': (0, 1),
#  'rejected': (0, 1),
#  'contaminated': (3, 1),
#  'uninitiated': (0, 1),
#  'relief': (0, 1),
#  'consecration': (1, 1),
#  'sinning': (1, 1),
#  'interested': (2, 1),
#  'unimproved': (0, 1),
#  'academy': (0, 1),
#  'sorely': (1, 1),
#  'fell': (1, 1),
#  'unimpressed': (0, 1),
#  'soulmate': (1, 1),
#  'untoward': (1, 1),
#  'asserting': (1, 1),
#  'ballot': (2, 1),
#  'dictatorial': (1, 1),
#  'monster': (1, 1),
#  'cold': (0, 1),
#  'pretensions': (0, 1),
#  'manifested': (0, 1),
#  'steadfast': (1, 1),
#  'leeway': (1, 1),
#  'legalized': (3, 1),
#  'porn': (1, 1),
#  'betterment': (0, 1),
#  'danger': (2, 1),
#  'intestate': (0, 1),
#  'everlasting': (0, 1),
#  'cheering': (0, 1),
#  'waste': (1, 1),
#  'lurking': (0, 1),
#  'opiate': (0, 1),
#  'erratum': (1, 1),
#  'passivity': (0, 1),
#  'represented': (0, 1),
#  'conscientious': (1, 1),
#  'bastard': (2, 1),
#  'wrong': (0, 1),
#  'exorcism': (2, 1),
#  'irritation': (3, 1),
#  'threaten': (2, 1),
#  'complicate': (1, 1),
#  'sweet': (0, 1),
#  'praised': (0, 1),
#  'firearms': (2, 1),
#  'strengthening': (1, 1),
#  'fault': (1, 1),
#  'bland': (0, 1),
#  'trendy': (0, 1),
#  'weakened': (0, 1),
#  'inspired': (0, 1),
#  'mutant': (0, 1),
#  'climax': (2, 1),
#  'feces': (1, 1),
#  'advance': (0, 1),
#  'luxuriant': (0, 1),
#  'admirer': (0, 1),
#  'chase': (0, 1),
#  'agility': (0, 1),
#  'study': (0, 1),
#  'violence': (3, 1),
#  'tumor': (0, 1),
#  'poke': (1, 1),
#  'impropriety': (0, 1),
#  'discards': (0, 1),
#  'absence': (0, 1),
#  'openness': (0, 1),
#  'presentable': (0, 1),
#  'distortion': (0, 1),
#  'persistence': (0, 1),
#  'advise': (1, 1),
#  'underpaid': (2, 1),
#  'romp': (0, 1),
#  'poorly': (0, 1),
#  'crisis': (0, 1),
#  'applause': (2, 1),
#  'proposition': (0, 1),
#  'detention': (1, 1),
#  'bore': (0, 1),
#  'dogged': (0, 1),
#  'royalty': (0, 1),
#  'recognizable': (0, 1),
#  'facts': (1, 1),
#  'trophy': (0, 1),
#  'bureaucracy': (1, 1),
#  'inaccurate': (0, 1),
#  'god': (3, 1),
#  'doit': (0, 1),
#  'ascent': (0, 1),
#  'scrumptious': (0, 1),
#  'sacrifices': (3, 1),
#  'eavesdropping': (0, 1),
#  'synchronize': (3, 1),
#  'essential': (0, 1),
#  'bad': (1, 1),
#  'sour': (0, 1),
#  'helplessness': (2, 1),
#  'affiliated': (0, 1),
#  'dull': (1, 1),
#  'hopeful': (3, 1),
#  'deceiving': (1, 1),
#  'oppose': (0, 1),
#  'heighten': (1, 1),
#  'celebrity': (4, 1),
#  'hydra': (1, 1),
#  'acceptance': (0, 1),
#  'faith': (1, 1),
#  'words': (1, 1),
#  'fancy': (0, 1),
#  'undo': (0, 1),
#  'exalt': (2, 1),
#  'incisive': (0, 1),
#  'warranty': (1, 1),
#  'fleece': (3, 1),
#  'dubious': (2, 1),
#  'naturalist': (0, 1),
#  'cyanide': (1, 1),
#  'earnestly': (0, 1),
#  'humility': (0, 1),
#  'heal': (1, 1),
#  'dumps': (1, 1),
#  'famous': (0, 1),
#  'impression': (0, 1),
#  'muzzle': (1, 1),
#  'loss': (1, 1),
#  'falling': (1, 1),
#  'freedom': (1, 1),
#  'cheesecake': (1, 1),
#  'cytomegalovirus': (1, 1),
#  'regulate': (0, 1),
#  'obliterated': (2, 1),
#  'exhaust': (0, 1),
#  'interlocutory': (0, 1),
#  'purity': (0, 1),
#  'resistive': (0, 1),
#  'panier': (0, 1),
#  'nightmare': (1, 1),
#  'foul': (3, 1),
#  'rating': (3, 1),
#  'denying': (1, 1),
#  'attraction': (0, 1),
#  'corrupt': (0, 1),
#  'whip': (1, 1),
#  'save': (1, 1),
#  'rejuvenated': (0, 1),
#  'bait': (2, 1),
#  'seasoned': (0, 1),
#  'boil': (1, 1),
#  'forward': (0, 1),
#  'aptitude': (0, 1),
#  'blower': (0, 1),
#  'hemorrhoids': (0, 1),
#  'nullify': (1, 1),
#  'idiot': (1, 1),
#  'mercenary': (1, 1),
#  'methanol': (0, 1),
#  'aground': (0, 1),
#  'pledge': (0, 1),
#  'moronic': (0, 1),
#  'severity': (0, 1),
#  'assurance': (1, 1),
#  'complexed': (0, 1),
#  'unsavory': (0, 1),
#  'commonwealth': (1, 1),
#  'poisoned': (4, 1),
#  'encourage': (0, 1),
#  'hug': (1, 1),
#  'row': (1, 1),
#  'smiling': (0, 1),
#  'farce': (0, 1),
#  'exterminate': (2, 1),
#  'bang': (5, 1),
#  'snide': (0, 1),
#  'enjoying': (0, 1),
#  'concussion': (2, 1),
#  'sloppy': (1, 1),
#  'boisterous': (2, 1),
#  'benefit': (0, 1),
#  'olfactory': (1, 1),
#  'present': (3, 1),
#  'cumbersome': (1, 1),
#  'mannered': (0, 1),
#  'savor': (4, 1),
#  'evasion': (2, 1),
#  'refuse': (0, 1),
#  'neglect': (0, 1),
#  'disclaim': (2, 1),
#  'smite': (3, 1),
#  'stifled': (3, 1),
#  'license': (0, 1),
#  'vanished': (3, 1),
#  'aristocracy': (0, 1),
#  'garnet': (0, 1),
#  'forgiving': (1, 1),
#  'visionary': (2, 1),
#  'rubbish': (1, 1),
#  'spelling': (0, 1),
#  'rough': (3, 1),
#  'refinement': (0, 1),
#  'famine': (1, 1),
#  'unacceptable': (1, 1),
#  'vigor': (0, 1),
#  'correction': (0, 1),
#  'blighted': (2, 1),
#  'imperfectly': (0, 1),
#  'roughness': (0, 1),
#  'construct': (0, 1),
#  'authorized': (0, 1),
#  'elevation': (2, 1),
#  'dedication': (0, 1),
#  'restful': (0, 1),
#  'pastime': (0, 1),
#  'vomiting': (0, 1),
#  'stroke': (2, 1),
#  'friendly': (2, 1),
#  'impotence': (2, 1),
#  'forfeited': (0, 1),
#  'adorable': (0, 1),
#  'qualifying': (0, 1),
#  'stupid': (0, 1),
#  'absenteeism': (0, 1),
#  'apathetic': (1, 1),
#  'harmony': (0, 1),
#  'irons': (1, 1),
#  'dabbling': (2, 1),
#  'tramp': (0, 1),
#  'chafing': (0, 1),
#  'gregarious': (0, 1),
#  'bonne': (0, 1),
#  'undermined': (0, 1),
#  'pained': (2, 1),
#  'cutting': (4, 1),
#  'rout': (0, 1),
#  'riot': (2, 1),
#  'endowed': (0, 1),
#  'fecal': (1, 1),
#  'doctor': (1, 1),
#  'grandeur': (0, 1),
#  'attenuated': (0, 1),
#  'compost': (1, 1),
#  'regretting': (1, 1),
#  'darkness': (3, 1),
#  'excruciating': (1, 1),
#  'bite': (2, 1),
#  'horrors': (2, 1),
#  'bully': (2, 1),
#  'decency': (0, 1),
#  'hurt': (3, 1),
#  'bitterly': (3, 1),
#  'productivity': (0, 1),
#  'gall': (0, 1),
#  'defamation': (2, 1),
#  'creditable': (1, 1),
#  'prevail': (1, 1),
#  'versus': (1, 1),
#  'wild': (1, 1),
#  'apostle': (1, 1),
#  'anchor': (0, 1),
#  'gross': (1, 1),
#  'tumour': (2, 1),
#  'elite': (2, 1),
#  'resignation': (2, 1),
#  'attacking': (5, 1),
#  'accord': (1, 1),
#  'pickle': (0, 1),
#  'indecision': (0, 1),
#  'achievement': (1, 1),
#  'gaunt': (0, 1),
#  'pregnancy': (1, 1),
#  'discharge': (0, 1),
#  'cooperation': (0, 1),
#  'influence': (1, 1),
#  'triumph': (0, 1),
#  'unforgiving': (2, 1),
#  'stellar': (0, 1),
#  'honorable': (1, 1),
#  'boo': (0, 1),
#  'ordained': (1, 1),
#  'implacable': (0, 1),
#  'erratic': (0, 1),
#  'producing': (0, 1),
#  'serpent': (2, 1),
#  'rigid': (0, 1),
#  'overthrow': (2, 1),
#  'gaining': (0, 1),
#  'overbearing': (1, 1),
#  'brutality': (2, 1),
#  'attractiveness': (0, 1),
#  'counselor': (1, 1),
#  'contravene': (0, 1),
#  'desert': (4, 1),
#  'cardiomyopathy': (2, 1),
#  'blessings': (3, 1),
#  'remarkably': (0, 1),
#  'visitation': (0, 1),
#  'highest': (3, 1),
#  'mate': (4, 1),
#  'breakup': (1, 1),
#  'accident': (3, 1),
#  'taint': (0, 1),
#  'practiced': (0, 1),
#  'discoloration': (1, 1),
#  'punctuality': (0, 1),
#  'credit': (1, 1),
#  'aggression': (2, 1),
#  'fatality': (2, 1),
#  'diversified': (0, 1),
#  'ornamented': (0, 1),
#  'encyclopedia': (1, 1),
#  'actionable': (2, 1),
#  'forbearance': (0, 1),
#  'gubernatorial': (1, 1),
#  'aid': (0, 1),
#  'error': (1, 1),
#  'nursery': (1, 1),
#  'faithful': (1, 1),
#  'crowning': (2, 1),
#  'angel': (3, 1),
#  'alabaster': (0, 1),
#  'grant': (2, 1),
#  'discipline': (1, 1),
#  'sincere': (1, 1),
#  'dwarfed': (2, 1),
#  'grudge': (1, 1),
#  'bilingual': (0, 1),
#  'sympathy': (1, 1),
#  'compassionate': (0, 1),
#  'incendiary': (3, 1),
#  'bark': (1, 1),
#  'gallantry': (0, 1),
#  'accusative': (0, 1),
#  'quiet': (1, 1),
#  'fireproof': (0, 1),
#  'protecting': (1, 1),
#  'admiral': (1, 1),
#  'antibiotics': (0, 1),
#  'patter': (1, 1),
#  'payback': (1, 1),
#  'hate': (3, 1),
#  'flaw': (0, 1),
#  'lower': (1, 1),
#  'concealment': (2, 1),
#  'rack': (1, 1),
#  'center': (1, 1),
#  'enforcement': (0, 1),
#  'sturdy': (0, 1),
#  'invalidity': (0, 1),
#  'dreadfully': (4, 1),
#  'delusional': (2, 1),
#  'disagreeing': (0, 1),
#  'glowing': (0, 1),
#  'manufacturer': (0, 1),
#  'birthplace': (1, 1),
#  'amazingly': (1, 1),
#  'absolution': (0, 1),
#  'guide': (1, 1),
#  'tantalizing': (2, 1),
#  'oligarchy': (0, 1),
#  'tipsy': (0, 1),
#  'supremacy': (1, 1),
#  'organized': (0, 1),
#  'emaciated': (2, 1),
#  'tenderness': (0, 1),
#  'patronizing': (0, 1),
#  'colonel': (1, 1),
#  'herpesvirus': (1, 1),
#  'perplexity': (0, 1),
#  'neighbor': (1, 1),
#  'virtue': (1, 1),
#  'content': (0, 1),
#  'welcomed': (0, 1),
#  'tax': (1, 1),
#  'maternal': (1, 1),
#  'horribly': (0, 1),
#  'tangled': (0, 1),
#  'pornography': (1, 1),
#  'checklist': (1, 1),
#  'fudge': (0, 1),
#  'snags': (1, 1),
#  'unwelcome': (1, 1),
#  'imperfection': (0, 1),
#  'gaby': (1, 1),
#  'customer': (0, 1),
#  'wit': (0, 1),
#  'expect': (3, 1),
#  'immaturity': (1, 1),
#  'usurped': (2, 1),
#  'prime': (0, 1),
#  'banshee': (4, 1),
#  'jornada': (0, 1),
#  'calls': (2, 1),
#  'oasis': (0, 1),
#  'armor': (2, 1),
#  'standstill': (1, 1),
#  'subject': (0, 1),
#  'irreducible': (0, 1),
#  'settlor': (1, 1),
#  'frolic': (0, 1),
#  'apache': (1, 1),
#  'corpse': (2, 1),
#  'embarrassing': (0, 1),
#  'falter': (1, 1),
#  'dislocated': (4, 1),
#  'unity': (1, 1),
#  'solid': (0, 1),
#  'dummy': (0, 1),
#  'cloudiness': (2, 1),
#  'torture': (5, 1),
#  'dependency': (0, 1),
#  'coercion': (4, 1),
#  'shot': (4, 1),
#  'endow': (1, 1),
#  'geranium': (0, 1),
#  'decayed': (2, 1),
#  'justice': (2, 1),
#  'smuggler': (3, 1),
#  'penetration': (2, 1),
#  'languish': (0, 1),
#  'deadlock': (0, 1),
#  'pull': (0, 1),
#  'interest': (0, 1),
#  'barbarism': (0, 1),
#  'casualty': (3, 1),
#  'cooperate': (0, 1),
#  'sweetie': (0, 1),
#  'happy': (0, 1),
#  'amphetamines': (1, 1),
#  'cutters': (0, 1),
#  'disallowed': (4, 1),
#  'impossible': (1, 1),
#  'elated': (0, 1),
#  'reaffirm': (0, 1),
#  'kudos': (0, 1),
#  'mess': (1, 1),
#  'quote': (2, 1),
#  'opinionated': (1, 1),
#  'blowout': (0, 1),
#  'wimpy': (4, 1),
#  'blot': (0, 1),
#  'destroying': (1, 1),
#  'completing': (1, 1),
#  'symmetry': (1, 1),
#  'intervention': (0, 1),
#  'unquestionably': (1, 1),
#  'privileged': (1, 1),
#  'baccalaureate': (0, 1),
#  'homesick': (1, 1),
#  'confuse': (1, 1),
#  'blind': (0, 1),
#  'suspicion': (1, 1),
#  'popularized': (0, 1),
#  'contributor': (1, 1),
#  'armaments': (1, 1),
#  'unfulfilled': (3, 1),
#  'dolphin': (2, 1),
#  'die': (2, 1),
#  'slate': (0, 1),
#  'strike': (1, 1),
#  'furor': (0, 1),
#  'gent': (3, 1),
#  'sunk': (3, 1),
#  'snarling': (1, 1),
#  'corruption': (1, 1),
#  'plagiarism': (0, 1),
#  'trembling': (1, 1),
#  'sex': (2, 1),
#  'misunderstanding': (0, 1),
#  'adder': (4, 1),
#  'surrendering': (1, 1),
#  'disorganized': (1, 1),
#  'rugged': (0, 1),
#  'godly': (1, 1),
#  'hippie': (0, 1),
#  'scavenger': (0, 1),
#  'hemorrhage': (3, 1),
#  'leave': (3, 1),
#  'fits': (1, 1),
#  'bias': (0, 1),
#  'litigant': (0, 1),
#  'doom': (1, 1),
#  'anathema': (5, 1),
#  'oak': (0, 1),
#  'ensemble': (1, 1),
#  'fuss': (2, 1),
#  'sore': (2, 1),
#  'perplexed': (0, 1),
#  'bluff': (0, 1),
#  'uninfected': (0, 1),
#  'din': (0, 1),
#  'truth': (1, 1),
#  'adrift': (0, 1),
#  'balance': (0, 1),
#  'score': (2, 1),
#  'spirit': (0, 1),
#  'fret': (1, 1),
#  'exuberance': (0, 1),
#  'idol': (0, 1),
#  'smelling': (1, 1),
#  'stress': (0, 1),
#  'oversight': (0, 1),
#  'discovery': (0, 1),
#  'plentiful': (0, 1),
#  'distressed': (1, 1),
#  'enablement': (1, 1),
#  'nefarious': (4, 1),
#  'sponge': (0, 1),
#  'egregious': (0, 1),
#  'heavily': (0, 1),
#  'goblin': (2, 1),
#  'incompetent': (2, 1),
#  'dance': (1, 1),
#  'drunken': (1, 1),
#  'dictatorship': (5, 1),
#  'superficial': (0, 1),
#  'teens': (0, 1),
#  'discriminate': (2, 1),
#  'surveying': (0, 1),
#  'green': (0, 1),
#  'campaigning': (2, 1),
#  'abolish': (1, 1),
#  'celebrated': (1, 1),
#  'unscrupulous': (0, 1),
#  'fume': (0, 1),
#  'unsustainable': (0, 1),
#  'abort': (0, 1),
#  'hobo': (1, 1),
#  'lowlands': (0, 1),
#  'obligor': (1, 1),
#  'weariness': (0, 1),
#  'tender': (1, 1),
#  'slur': (2, 1),
#  'somatic': (1, 1),
#  'drone': (0, 1),
#  'committed': (1, 1),
#  'grated': (1, 1),
#  'samurai': (1, 1),
#  'standoff': (2, 1),
#  'complicated': (0, 1),
#  'creaking': (0, 1),
#  'interference': (0, 1),
#  'dysentery': (2, 1),
#  'fainting': (3, 1),
#  'profession': (1, 1),
#  'love': (0, 1),
#  'cleaning': (0, 1),
#  'worried': (1, 1),
#  'timely': (0, 1),
#  'untitled': (1, 1),
#  'disapproved': (2, 1),
#  'mending': (0, 1),
#  'pain': (2, 1),
#  'polish': (0, 1),
#  'specie': (1, 1),
#  'divinity': (0, 1),
#  'genius': (0, 1),
#  'cruelly': (2, 1),
#  'tranquil': (0, 1),
#  'gonorrhea': (4, 1),
#  'beverage': (0, 1),
#  'lost': (1, 1),
#  'biblical': (0, 1),
#  'inequitable': (0, 1),
#  'reporter': (1, 1),
#  'mutilated': (1, 1),
#  'countess': (0, 1),
#  'upset': (2, 1),
#  'array': (0, 1),
#  'clashing': (0, 1),
#  'bonds': (0, 1),
#  'dismemberment': (3, 1),
#  'brotherhood': (1, 1),
#  'scrapie': (3, 1),
#  'conflagration': (2, 1),
#  'motherhood': (1, 1),
#  'despair': (3, 1),
#  'specter': (2, 1),
#  'uninteresting': (1, 1),
#  'torpedo': (1, 1),
#  'distracted': (0, 1),
#  'accuser': (2, 1),
#  'accused': (0, 1),
#  'frown': (1, 1),
#  'fearing': (1, 1),
#  'fury': (1, 1),
#  'bound': (0, 1),
#  'autocratic': (0, 1),
#  'clash': (1, 1),
#  'defense': (0, 1),
#  'prospect': (0, 1),
#  'grit': (1, 1),
#  'growl': (0, 1),
#  'puppy': (2, 1),
#  'vote': (5, 1),
#  'haunt': (1, 1),
#  'setback': (1, 1),
#  'rage': (2, 1),
#  'nul': (0, 1),
#  'justification': (0, 1),
#  'pinion': (1, 1),
#  'babbling': (0, 1),
#  'unique': (0, 1),
#  'rejection': (2, 1),
#  'sublimation': (0, 1),
#  'peculiarities': (0, 1),
#  'deceived': (1, 1),
#  'annihilated': (3, 1),
#  'hoot': (2, 1),
#  'shock': (3, 1),
#  'enmity': (2, 1),
#  'dependence': (2, 1),
#  'gallant': (0, 1),
#  'powerless': (2, 1),
#  'incense': (1, 1),
#  'slip': (0, 1),
#  'ineffective': (0, 1),
#  'abandon': (2, 1),
#  'routine': (1, 1),
#  'extraordinary': (0, 1),
#  'detection': (0, 1),
#  'importance': (0, 1),
#  'absorbed': (0, 1),
#  'swear': (1, 1),
#  'shortcoming': (0, 1),
#  'filibuster': (0, 1),
#  'fanatic': (0, 1),
#  'disparity': (3, 1),
#  'respecting': (0, 1),
#  'exaggerate': (1, 1),
#  'tutelage': (1, 1),
#  'experienced': (2, 1),
#  'denunciation': (1, 1),
#  'ancient': (0, 1),
#  'serene': (1, 1),
#  'awful': (4, 1),
#  'splendor': (0, 1),
#  'disregard': (0, 1),
#  'garish': (0, 1),
#  'celebrating': (1, 1),
#  'superiority': (0, 1),
#  'mortification': (2, 1),
#  'tough': (2, 1),
#  'burn': (2, 1),
#  'authorization': (1, 1),
#  'spree': (0, 1),
#  'annoying': (1, 1),
#  'cage': (1, 1),
#  'join': (0, 1),
#  'unequivocally': (0, 1),
#  'chairman': (1, 1),
#  'betrayal': (3, 1),
#  'hit': (2, 1),
#  'radiant': (0, 1),
#  'crude': (1, 1),
#  'special': (1, 1),
#  'defending': (0, 1),
#  'horrid': (4, 1),
#  'conflict': (2, 1),
#  'adulterated': (0, 1),
#  'debate': (0, 1),
#  'alluring': (0, 1),
#  'aloha': (1, 1),
#  'environ': (0, 1),
#  'embroiled': (0, 1),
#  'kindred': (0, 1),
#  'battlefield': (1, 1),
#  'perk': (1, 1),
#  'advanced': (0, 1),
#  'scab': (0, 1),
#  'halting': (2, 1),
#  'moron': (0, 1),
#  'guard': (2, 1),
#  'verge': (2, 1),
#  'lie': (0, 1),
#  'poaching': (4, 1),
#  'notables': (0, 1),
#  'battled': (3, 1),
#  'alcoholism': (4, 1),
#  'depreciation': (1, 1),
#  'democracy': (0, 1),
#  'skewed': (2, 1),
#  'alleviation': (0, 1),
#  'unpublished': (2, 1),
#  'enlighten': (0, 1),
#  'timidity': (2, 1),
#  'sneak': (0, 1),
#  'agree': (0, 1),
#  'smitten': (0, 1),
#  'pervert': (0, 1),
#  'instruction': (1, 1),
#  'corrupting': (4, 1),
#  'hurrah': (0, 1),
#  'windfall': (0, 1),
#  'extinct': (0, 1),
#  'scrambling': (0, 1),
#  'candid': (1, 1),
#  'deadly': (3, 1),
#  'dissolution': (4, 1),
#  'ardent': (0, 1),
#  'modesty': (0, 1),
#  'conserve': (0, 1),
#  'pretense': (0, 1),
#  'spoil': (1, 1),
#  'mimicry': (0, 1),
#  'contribute': (0, 1),
#  'peck': (0, 1),
#  'buzzed': (0, 1),
#  'quiver': (1, 1),
#  'force': (2, 1),
#  'share': (0, 1),
#  'partnership': (1, 1),
#  'unwavering': (1, 1),
#  'caries': (1, 1),
#  'execution': (3, 1),
#  'reciprocate': (0, 1),
#  'doldrums': (1, 1),
#  'barred': (0, 1),
#  'offensive': (2, 1),
#  'heroine': (1, 1),
#  'magnificence': (2, 1),
#  'fall': (0, 1),
#  'dirty': (1, 1),
#  'soiled': (1, 1),
#  'disillusionment': (4, 1),
#  'boilerplate': (0, 1),
#  'plexus': (0, 1),
#  'stiff': (0, 1),
#  'cramp': (1, 1),
#  'worsening': (2, 1),
#  'sting': (1, 1),
#  'noble': (1, 1),
#  'valor': (1, 1),
#  'tumble': (0, 1),
#  'fleshy': (0, 1),
#  'empathy': (0, 1),
#  'civilized': (1, 1),
#  'trash': (1, 1),
#  'savage': (2, 1),
#  'endure': (0, 1),
#  'evolution': (0, 1),
#  'disappointing': (1, 1),
#  'amenable': (0, 1),
#  'tickle': (3, 1),
#  'cooperating': (1, 1),
#  'flounder': (1, 1),
#  'swastika': (2, 1),
#  'contrary': (0, 1),
#  'escape': (2, 1),
#  'busted': (2, 1),
#  'superb': (0, 1),
#  'defender': (1, 1),
#  'wince': (1, 1),
#  'grounded': (2, 1),
#  'potable': (0, 1),
#  'cocaine': (1, 1),
#  'deficiency': (0, 1),
#  'derision': (1, 1),
#  'stools': (1, 1),
#  'cult': (1, 1),
#  'recreation': (1, 1),
#  'bothering': (2, 1),
#  'planning': (2, 1),
#  'curse': (4, 1),
#  'rekindle': (3, 1),
#  'dazed': (0, 1),
#  'deflation': (2, 1),
#  'assent': (0, 1),
#  'siren': (1, 1),
#  'disastrous': (1, 1),
#  'redemption': (0, 1),
#  'broken': (2, 1),
#  'maroon': (0, 1),
#  'abscess': (1, 1),
#  'deal': (1, 1),
#  'outlaw': (0, 1),
#  'crushing': (3, 1),
#  'standing': (0, 1),
#  'readiness': (2, 1),
#  'opposition': (0, 1),
#  'disqualified': (3, 1),
#  'salute': (0, 1),
#  'shambles': (1, 1),
#  'guzzling': (0, 1),
#  'depressive': (1, 1),
#  'demand': (0, 1),
#  'plush': (0, 1),
#  'pinnacle': (0, 1),
#  'formula': (1, 1),
#  'conciliation': (0, 1),
#  'unapproved': (0, 1),
#  'ruffle': (0, 1),
#  'suffer': (0, 1),
#  'unfortunate': (1, 1),
#  'quicksilver': (2, 1),
#  'demon': (1, 1),
#  'fuming': (1, 1),
#  'irresponsible': (0, 1),
#  'lapse': (0, 1),
#  'reject': (0, 1),
#  'wireless': (4, 1),
#  'daemon': (5, 1),
#  'ovation': (1, 1),
#  'speculation': (2, 1),
#  'overjoyed': (0, 1),
#  'weight': (3, 1),
#  'rota': (1, 1),
#  'rabies': (0, 1),
#  'feudalism': (2, 1),
#  'choral': (0, 1),
#  'collapse': (0, 1),
#  'sensuality': (1, 1),
#  'absolute': (0, 1),
#  'snarl': (2, 1),
#  'fulfill': (0, 1),
#  'bummer': (2, 1),
#  'aristocratic': (0, 1),
#  'divested': (0, 1),
#  'deletion': (0, 1),
#  'attenuation': (1, 1),
#  'segregated': (0, 1),
#  'endeavor': (1, 1),
#  'rapture': (1, 1),
#  'orgasm': (1, 1),
#  'splendid': (1, 1),
#  'nonsensical': (1, 1),
#  'repudiation': (2, 1),
#  'deceased': (1, 1),
#  'rest': (0, 1),
#  'treat': (0, 1),
#  'aphid': (1, 1),
#  'crypt': (1, 1),
#  'liberty': (0, 1),
#  'superior': (1, 1),
#  'entangled': (4, 1),
#  'woefully': (2, 1),
#  'odor': (0, 1),
#  'fool': (1, 1),
#  'choke': (0, 1),
#  'nurture': (1, 1),
#  'revolution': (1, 1),
#  'merge': (1, 1),
#  'imitated': (0, 1),
#  'strip': (1, 1),
#  'bizarre': (1, 1),
#  'ruin': (2, 1),
#  'remedy': (0, 1),
#  'bribe': (0, 1),
#  'conjuring': (0, 1),
#  'embrace': (3, 1),
#  'denied': (2, 1),
#  'afflicted': (0, 1),
#  'devotional': (1, 1),
#  'gloss': (0, 1),
#  'irrelevant': (0, 1),
#  'insolvency': (0, 1),
#  'stain': (0, 1),
#  'firmness': (0, 1),
#  'cigarette': (0, 1),
#  'negative': (1, 1),
#  'atom': (0, 1),
#  'desperate': (0, 1),
#  'smack': (1, 1),
#  'glorify': (3, 1),
#  'terrorist': (4, 1),
#  'task': (0, 1),
#  'advisable': (1, 1),
#  'incase': (4, 1),
#  'dementia': (2, 1),
#  'outrage': (2, 1),
#  'opportune': (0, 1),
#  'consummate': (0, 1),
#  'mite': (0, 1),
#  'fade': (0, 1),
#  'toils': (0, 1),
#  'unaccountable': (4, 1),
#  'antifungal': (1, 1),
#  'stumble': (0, 1),
#  'skilled': (0, 1),
#  'notable': (1, 1),
#  'agreement': (0, 1),
#  'undecided': (0, 1),
#  'kindness': (0, 1),
#  'unbiased': (0, 1),
#  'innocent': (0, 1),
#  'pharmaceutical': (0, 1),
#  'helpful': (1, 1),
#  'muss': (1, 1),
#  'bargain': (0, 1),
#  'shattered': (0, 1),
#  'disinformation': (2, 1),
#  'riddled': (0, 1),
#  'uncertainty': (2, 1),
#  'overpaid': (1, 1),
#  'glib': (0, 1),
#  'starved': (0, 1),
#  'shiver': (4, 1),
#  'retraction': (1, 1),
#  'good': (3, 1),
#  'caricature': (0, 1),
#  'neurotic': (2, 1),
#  'constant': (0, 1),
#  'renegade': (0, 1),
#  'forewarned': (2, 1),
#  'pungent': (1, 1),
#  'peace': (1, 1),
#  'scandal': (1, 1),
#  'generosity': (3, 1),
#  'merciless': (1, 1),
#  'abuse': (4, 1),
#  'vacation': (1, 1),
#  'staccato': (0, 1),
#  'assistance': (0, 1),
#  'regal': (1, 1),
#  'solvency': (0, 1),
#  'infallible': (0, 1),
#  'despise': (2, 1),
#  'crusty': (1, 1),
#  'apprehension': (1, 1),
#  'enable': (1, 1),
#  'retribution': (0, 1),
#  'overpriced': (3, 1),
#  'atone': (0, 1),
#  'rejuvenate': (0, 1),
#  'coronation': (0, 1),
#  'asshole': (2, 1),
#  'concord': (2, 1),
#  'growling': (3, 1),
#  'model': (0, 1),
#  'grace': (0, 1),
#  'defect': (0, 1),
#  'weary': (1, 1),
#  'shelved': (0, 1),
#  'frayed': (1, 1),
#  'dismay': (4, 1),
#  ...}

# %%
senseWords
# Out:
# {'paraphrase',
#  'virulence',
#  'aggressor',
#  'complexity',
#  'tolerate',
#  'prove',
#  'erratum',
#  'theism',
#  'delayed',
#  'innovate',
#  'fasting',
#  'champion',
#  'disregarded',
#  'fair',
#  'intellectual',
#  'organization',
#  'foolish',
#  'disorder',
#  'phony',
#  'resign',
#  'tribulation',
#  'failing',
#  'ken',
#  'homosexuality',
#  'butt',
#  'usual',
#  'uninitiated',
#  'relief',
#  'compliance',
#  'unimproved',
#  'academy',
#  'fell',
#  'untoward',
#  'dictatorial',
#  'monster',
#  'restriction',
#  'danger',
#  'critic',
#  'irregularity',
#  'apologize',
#  'lurking',
#  'opiate',
#  'silly',
#  'conscientious',
#  'patience',
#  'exile',
#  'strengthening',
#  'poke',
#  'ancient',
#  'absence',
#  'suppress',
#  'presentable',
#  'distortion',
#  'advise',
#  'romp',
#  'revise',
#  'dogged',
#  'recognizable',
#  'trophy',
#  'prestige',
#  'doit',
#  'reorganize',
#  'contentious',
#  'sacrifices',
#  'eavesdropping',
#  'treat',
#  'sour',
#  'helplessness',
#  'thrift',
#  'adjunct',
#  'words',
#  'undo',
#  'admiration',
#  'cyanide',
#  'rail',
#  'slaughtering',
#  'prophylactic',
#  'obliterated',
#  'revere',
#  'reactionary',
#  'insufficiency',
#  'blower',
#  'vindicated',
#  'idiot',
#  'methanol',
#  'moronic',
#  'advance',
#  'complexed',
#  'quack',
#  'poisoned',
#  'evil',
#  'hug',
#  'farce',
#  'bang',
#  'grudge',
#  'discretion',
#  'olfactory',
#  'cumbersome',
#  'crack',
#  'refuse',
#  'stone',
#  'vanished',
#  'director',
#  'rubbish',
#  'unacceptable',
#  'roughness',
#  'construct',
#  'glide',
#  'dwarfed',
#  'radiant',
#  'impotence',
#  'ripen',
#  'grieve',
#  'harmony',
#  'exquisite',
#  'moderate',
#  'cutting',
#  'rout',
#  'riot',
#  'endowed',
#  'compost',
#  'excruciating',
#  'jubilee',
#  'standoff',
#  'bitterly',
#  'wane',
#  'tumour',
#  'sentinel',
#  'attacking',
#  'halting',
#  'pickle',
#  'pregnancy',
#  'cooperation',
#  'modesty',
#  'gossip',
#  'passion',
#  'crash',
#  'presence',
#  'serpent',
#  'lurch',
#  'soak',
#  'denied',
#  'dementia',
#  'dispersion',
#  'incompetence',
#  'scaffold',
#  'crowning',
#  'resisting',
#  'angel',
#  'ally',
#  'grant',
#  'nervous',
#  'precedence',
#  'cry',
#  'intimate',
#  'dawn',
#  'fret',
#  'accusative',
#  'efficient',
#  'reverence',
#  'study',
#  'antibiotics',
#  'unsatisfied',
#  'flaw',
#  'lower',
#  'concealment',
#  'rack',
#  'illustrate',
#  'enforcement',
#  'consecration',
#  'luxuriant',
#  'uninterested',
#  'word',
#  'disagreeing',
#  'intelligence',
#  'shell',
#  'amazingly',
#  'guide',
#  'facts',
#  'tantalizing',
#  'horrible',
#  'tipsy',
#  'tenacious',
#  'tenderness',
#  'marked',
#  'fecal',
#  'patronizing',
#  'row',
#  'welcomed',
#  'fudge',
#  'unauthorized',
#  'unwelcome',
#  'monstrosity',
#  'immaturity',
#  'punctuality',
#  'calls',
#  'sympathy',
#  'armor',
#  'partisan',
#  'majority',
#  'geranium',
#  'dummy',
#  'margin',
#  'thoroughbred',
#  'stationary',
#  'blunder',
#  'languish',
#  'wit',
#  'happy',
#  'shabby',
#  'default',
#  'impossible',
#  'kudos',
#  'defiance',
#  'quote',
#  'limp',
#  'wimpy',
#  'blot',
#  'outlandish',
#  'aura',
#  'confuse',
#  'reinforcement',
#  'menses',
#  'dolphin',
#  'infarct',
#  'snarling',
#  'deflation',
#  'rugged',
#  'possess',
#  'uninfected',
#  'uncertainty',
#  'chore',
#  'oversight',
#  'discovery',
#  'sponge',
#  'heavily',
#  'smoothness',
#  'green',
#  'disturbance',
#  'march',
#  'grandeur',
#  'fume',
#  'confine',
#  'tender',
#  'somatic',
#  'crook',
#  'poaching',
#  'complicated',
#  'wealth',
#  'polish',
#  'propaganda',
#  'cruelly',
#  'council',
#  'lost',
#  'evade',
#  'inequitable',
#  'fleet',
#  'mutilated',
#  'bonds',
#  'dismemberment',
#  'scrapie',
#  'uninteresting',
#  'accused',
#  'fury',
#  'crunch',
#  'including',
#  'breakfast',
#  'rod',
#  'pinion',
#  'babbling',
#  'annihilated',
#  'phantom',
#  'difficulty',
#  'swear',
#  'disparity',
#  'mishap',
#  'splendor',
#  'garish',
#  'undying',
#  'superiority',
#  'effective',
#  'junta',
#  'spree',
#  'smother',
#  'cage',
#  'unequivocally',
#  'chairman',
#  'sage',
#  'conflict',
#  'enforce',
#  'emulate',
#  'chisel',
#  'skewed',
#  'unpublished',
#  'palsy',
#  'eagerness',
#  'glory',
#  'imperfection',
#  'pervert',
#  'corrupting',
#  'windfall',
#  'extinct',
#  'scrambling',
#  'lump',
#  'ardent',
#  'mimicry',
#  'quiver',
#  'doldrums',
#  'heroine',
#  'fall',
#  'rejected',
#  'sting',
#  'inadequate',
#  'tickle',
#  'pay',
#  'demonstrative',
#  'deficiency',
#  'advocacy',
#  'venomous',
#  'blighted',
#  'bothering',
#  'planning',
#  'broken',
#  'remarkably',
#  'received',
#  'outlaw',
#  'crushing',
#  'outcry',
#  'plush',
#  'mediocrity',
#  'shoddy',
#  'ruffle',
#  'torture',
#  'indecision',
#  'ovation',
#  'rooted',
#  'brawl',
#  'sensuality',
#  'forgery',
#  'endeavor',
#  'rapture',
#  'orgasm',
#  'safe',
#  'deceased',
#  'organize',
#  'superior',
#  'choke',
#  'revolution',
#  'mother',
#  'afflicted',
#  'sisterhood',
#  'quaint',
#  'spectacle',
#  'jargon',
#  'atom',
#  'desperate',
#  'smack',
#  'task',
#  'advisable',
#  'constraint',
#  'balm',
#  'tower',
#  'redress',
#  'racket',
#  'depression',
#  'rescue',
#  'blush',
#  'conviction',
#  'kindness',
#  'unbiased',
#  'perturbation',
#  'pharmaceutical',
#  'hanging',
#  'delegate',
#  'mob',
#  'captivate',
#  'shattered',
#  'hasty',
#  'volunteer',
#  'caricature',
#  'neurotic',
#  'indefensible',
#  'pungent',
#  'merciless',
#  'regal',
#  'expatriate',
#  'absent',
#  'infallible',
#  'enable',
#  'overpriced',
#  'atone',
#  'rejuvenate',
#  'asshole',
#  'growling',
#  'grace',
#  'weary',
#  'shelved',
#  'dismay',
#  'paralysis',
#  'grotesque',
#  'tumult',
#  'lackluster',
#  'authoritative',
#  'addresses',
#  'greatness',
#  'soil',
#  'withstand',
#  'humble',
#  'perplexity',
#  'bitterness',
#  'domination',
#  'buffet',
#  'desiring',
#  'case',
#  'languid',
#  'scab',
#  'storm',
#  'contradict',
#  'liberty',
#  'humiliating',
#  'cultivate',
#  'sonorous',
#  'endangered',
#  'stint',
#  'resigned',
#  'pith',
#  'reason',
#  'routine',
#  'accueil',
#  'disliked',
#  'classics',
#  'damper',
#  'depreciate',
#  'omen',
#  'irrevocable',
#  'raptors',
#  'disable',
#  'hush',
#  'license',
#  'constancy',
#  'alluring',
#  'delinquency',
#  'labor',
#  'beggar',
#  'shed',
#  'drawback',
#  'precious',
#  'communicate',
#  'inadmissible',
#  'decay',
#  'medal',
#  'crusade',
#  'resistant',
#  'litigate',
#  'lettered',
#  'detect',
#  'examination',
#  'continue',
#  'hindrance',
#  'pessimist',
#  'spice',
#  'sky',
#  'garrison',
#  'determination',
#  'republic',
#  'undesired',
#  'musical',
#  'gang',
#  'tribute',
#  'absentee',
#  'madden',
#  'spotless',
#  'staring',
#  'banish',
#  'waste',
#  'heroism',
#  'equilibrium',
#  'fervor',
#  'infinite',
#  'humility',
#  'graciously',
#  'reparation',
#  'dispute',
#  'affront',
#  'tiresome',
#  'picketing',
#  'defamation',
#  'intelligent',
#  'mockery',
#  'swelling',
#  'cardiomyopathy',
#  'frayed',
#  'forbearance',
#  'contaminated',
#  'ornamented',
#  'worship',
#  'resident',
#  'ravenous',
#  'copy',
#  'hire',
#  'babble',
#  'tangled',
#  'pretensions',
#  'instrumental',
#  'steadfast',
#  'impervious',
#  'betterment',
#  'exorcism',
#  'complicate',
#  'sweet',
#  'teens',
#  'fault',
#  'fat',
#  'inspired',
#  'admirer',
#  'lace',
#  'retract',
#  'intrusion',
#  'join',
#  'organic',
#  'sing',
#  'crisis',
#  'bureaucracy',
#  'choral',
#  'sea',
#  'heighten',
#  'hydra',
#  'flagrant',
#  'faith',
#  'moderator',
#  'cream',
#  'conceal',
#  'dubious',
#  'earnestly',
#  'heal',
#  'tarnish',
#  'impression',
#  'communism',
#  'muzzle',
#  'falling',
#  'injured',
#  'cytomegalovirus',
#  'remove',
#  'resistive',
#  'panier',
#  'foul',
#  'expel',
#  'wot',
#  'epitome',
#  'nullify',
#  'associate',
#  'expect',
#  'aground',
#  'interested',
#  'severity',
#  'cunning',
#  'sloppy',
#  'present',
#  'inconsequential',
#  'sap',
#  'evasion',
#  'remarkable',
#  'prominence',
#  'flinch',
#  'adultery',
#  'restful',
#  'visionary',
#  'imitated',
#  'famine',
#  'correction',
#  'blessings',
#  'convert',
#  'pet',
#  'imperfectly',
#  'gag',
#  'dedication',
#  'absolution',
#  'qualifying',
#  'quell',
#  'grumpy',
#  'tramp',
#  'chafing',
#  'wrench',
#  'gift',
#  'pained',
#  'objective',
#  'garden',
#  'doctor',
#  'stress',
#  'horrors',
#  'hurt',
#  'productivity',
#  'versus',
#  'wild',
#  'levy',
#  'full',
#  'elite',
#  'resignation',
#  'rear',
#  'ferment',
#  'discharge',
#  'fidelity',
#  'influence',
#  'cradle',
#  'unsatisfactory',
#  'ordained',
#  'implacable',
#  'bounty',
#  'rigid',
#  'idiotic',
#  'counselor',
#  'performer',
#  'visitation',
#  'exacerbate',
#  'taint',
#  'practiced',
#  'aggression',
#  'solidity',
#  'nepotism',
#  'desolation',
#  'deluge',
#  'tempest',
#  'uncertain',
#  'hidden',
#  'remission',
#  'suck',
#  'clearance',
#  'gallantry',
#  'quiet',
#  'patter',
#  'payback',
#  'hate',
#  'art',
#  'surveying',
#  'flush',
#  'invalidity',
#  'sturdy',
#  'wages',
#  'bless',
#  'herpesvirus',
#  'content',
#  'horribly',
#  'expedition',
#  'agreement',
#  'ram',
#  'count',
#  'completion',
#  'gaby',
#  'split',
#  'hiss',
#  'advent',
#  'usurped',
#  'jornada',
#  'oasis',
#  'standstill',
#  'settlor',
#  'embarrassing',
#  'falter',
#  'perennial',
#  'inconsiderate',
#  'warp',
#  'familiarity',
#  'deadlock',
#  'bonus',
#  'casualty',
#  'spirit',
#  'dictatorship',
#  'cutters',
#  'profession',
#  'abduction',
#  'adverse',
#  'opinionated',
#  'explain',
#  'destroying',
#  'prudence',
#  'baccalaureate',
#  'respite',
#  'unfulfilled',
#  'strike',
#  'opposition',
#  'disorganized',
#  'leave',
#  'litigant',
#  'doom',
#  'anathema',
#  'marry',
#  'innocent',
#  'garnish',
#  'truth',
#  'balance',
#  'exuberance',
#  'idol',
#  'craft',
#  'instinctive',
#  'yawn',
#  'goblin',
#  'dishonor',
#  'drunken',
#  'abolish',
#  'income',
#  'unscrupulous',
#  'alabaster',
#  'unsustainable',
#  'lowlands',
#  'obligor',
#  'labored',
#  'noose',
#  'grated',
#  'love',
#  'arrogant',
#  'worried',
#  'disapproved',
#  'showy',
#  'specie',
#  'discrimination',
#  'genius',
#  'peck',
#  'interlocutory',
#  'unpredictable',
#  'biblical',
#  'reporter',
#  'upset',
#  'barrier',
#  'aristocracy',
#  'array',
#  'brotherhood',
#  'stupid',
#  'officer',
#  'grasping',
#  'accuser',
#  'frown',
#  'aberration',
#  'battery',
#  'powerful',
#  'commutation',
#  'homage',
#  'salvation',
#  'rhythm',
#  'sublimation',
#  'peculiarities',
#  'vagueness',
#  'dependence',
#  'privileged',
#  'slip',
#  'ineffective',
#  'shortcoming',
#  'reading',
#  'filibuster',
#  'denunciation',
#  'drown',
#  'serene',
#  'aloof',
#  'disregard',
#  'buck',
#  'vertigo',
#  'abomination',
#  'orderly',
#  'authorization',
#  'confess',
#  'grate',
#  'refractory',
#  'pretense',
#  'contribute',
#  'defending',
#  'accompaniment',
#  'tripping',
#  'battlefield',
#  'alcoholism',
#  'acrobat',
#  'prick',
#  'agree',
#  'smitten',
#  'campaigning',
#  'solvency',
#  'worm',
#  'rational',
#  'conserve',
#  'spoil',
#  'genial',
#  'punctual',
#  'servant',
#  'share',
#  'partnership',
#  'confidence',
#  'boilerplate',
#  'disillusionment',
#  'stiff',
#  'cramp',
#  'whirlwind',
#  'worsening',
#  'supremacy',
#  'sunk',
#  'empathy',
#  'trash',
#  'savage',
#  'endure',
#  'evolution',
#  'fate',
#  'civilized',
#  'pioneer',
#  'cooperating',
#  'flounder',
#  'swastika',
#  'escape',
#  'deceiving',
#  'defender',
#  'female',
#  'benevolence',
#  'sinning',
#  'potable',
#  'derision',
#  'nurse',
#  'rekindle',
#  'redemption',
#  'shambles',
#  'thrilling',
#  'rencontre',
#  'emaciated',
#  'unfortunate',
#  'antagonistic',
#  'demon',
#  'fumble',
#  'irresponsible',
#  'wireless',
#  'daemon',
#  'plunge',
#  'relaxation',
#  'feudalism',
#  'collapse',
#  'illusion',
#  'deliberate',
#  'merge',
#  'incorrect',
#  'restraint',
#  'nonsensical',
#  'vote',
#  'aphid',
#  'crypt',
#  'bailiff',
#  'unconstrained',
#  'nurture',
#  'gloss',
#  'animosity',
#  'firmness',
#  'negative',
#  'formula',
#  'rust',
#  'manly',
#  'untold',
#  'opportune',
#  'harvest',
#  'resistance',
#  'unaccountable',
#  'palliative',
#  'muss',
#  'winnings',
#  'shiver',
#  'dictionary',
#  'brutality',
#  'forewarned',
#  'amend',
#  'impress',
#  'scandal',
#  'legendary',
#  'abuse',
#  'vacation',
#  'staccato',
#  'noncompliance',
#  'cocaine',
#  'exhaust',
#  'comprehend',
#  'mediation',
#  'crusty',
#  'charm',
#  'apprehension',
#  'lordship',
#  'agility',
#  'repress',
#  'romance',
#  'craftsman',
#  'cathartic',
#  'murky',
#  'praise',
#  'virtuous',
#  'somber',
#  'adventure',
#  'preserve',
#  'doubt',
#  'recovery',
#  'travesty',
#  'rubble',
#  'blast',
#  'supporter',
#  'lash',
#  'subjected',
#  'land',
#  'reserve',
#  'favoritism',
#  'dashed',
#  'concluding',
#  'unexplained',
#  'vanity',
#  'samurai',
#  'dun',
#  'ridiculous',
#  'varicose',
#  'aiding',
#  'strut',
#  'fade',
#  'intact',
#  'untie',
#  'debate',
#  'defeat',
#  'iron',
#  'tact',
#  'evergreen',
#  'jarring',
#  'enchanting',
#  'complication',
#  'winner',
#  'flap',
#  'bargain',
#  'blob',
#  'notable',
#  'endowment',
#  'barricade',
#  'verve',
#  'destroyed',
#  'piles',
#  'unbeaten',
#  'attraction',
#  'unscathed',
#  'fairly',
#  'credited',
#  'injunction',
#  'failure',
#  'assassinate',
#  'shoulder',
#  'playhouse',
#  'receiving',
#  'revive',
#  'subjugation',
#  'birth',
#  'anaconda',
#  'discourage',
#  'bland',
#  'mutant',
#  'dust',
#  'kitten',
#  'acquiring',
#  'lacking',
#  'prohibition',
#  'inaccurate',
#  'oppose',
#  'acceptance',
#  'struggle',
#  'vegetative',
#  'revival',
#  'cute',
#  'originality',
#  'excluding',
#  'neglecting',
#  'main',
#  'substance',
#  'martyrdom',
#  'elect',
#  'despise',
#  'pretending',
#  'ballot',
#  'banshee',
#  'leeway',
#  'legalized',
#  'concealed',
#  'offhand',
#  'irrational',
#  'everlasting',
#  'completing',
#  'hive',
#  'fuss',
#  'irritation',
#  'praised',
#  'weakened',
#  'impropriety',
#  'persistence',
#  'underpaid',
#  'sullen',
#  'luxury',
#  'applause',
#  'reconciliation',
#  'royalty',
#  'kick',
#  'standing',
#  'exclusion',
#  'deterioration',
#  'lapse',
#  'ascent',
#  'synchronize',
#  'bad',
#  'enjoy',
#  'earnest',
#  ...}
