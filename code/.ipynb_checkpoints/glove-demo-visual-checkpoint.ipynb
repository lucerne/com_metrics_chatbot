# %%
import spacy
import numpy as np
import matplotlib.pyplot as plt
import os
import statistics 
import seaborn as sns

# %%
if __name__ == "__main__":
    filename = "/home/luluvyd/corpus/GloVe/vectors.txt"
    
    maxCount = 100
    count = 0
    
    with open(filename, 'r') as file: 
        for v in file:  
            if count < maxCount: 
                print(file.readline())
                count += 1 
            else: 
                break 
                
    filename = "/home/luluvyd/corpus/GloVe/vocab.txt"
    
    words = []
    freq = []
    with open(filename, 'r') as file: 
        for line in file: 
            l = line.split()
            words.append(l[0])
            freq.append(l[1])
    file.close()
# Out:
# of 0.657803 -0.200800 0.777343 0.364548 -0.454381 0.380461 1.022095 -0.176488 -0.995795 0.080785 -1.281497 -1.009708 -0.080341 1.059671 -0.100797 -0.649157 0.300103 -0.625649 -0.684488 0.087718 0.890724 -0.088393 -0.382092 0.335878 -1.003701 -0.677195 -0.238741 -0.236728 -0.761994 -0.603262 -1.113812 0.069966 -1.777288 -1.216935 2.889780 -1.039200 1.045409 -0.565530 -0.031572 -1.907623 -0.105710 -0.995466 -0.325790 -0.552982 -0.798418 -0.138046 -0.086748 -0.414438 0.248192 2.393769
#
# one -0.630379 -0.669397 0.278484 -0.662977 -0.783239 0.524149 0.585949 -1.180432 -1.133205 0.931890 -1.360104 -0.748189 0.130430 0.106417 -1.304673 -0.256558 0.037999 0.253154 -0.367079 -1.191094 0.870910 -1.086657 0.050690 -1.035073 -1.152546 0.036785 -0.444747 0.028657 0.409722 -1.062485 -0.873856 -0.563527 -1.238933 -0.981007 2.279975 -1.508913 0.766029 -0.666412 -0.174376 -0.780111 0.099520 -0.430907 -0.337954 -0.927502 1.383625 -0.281972 0.429904 -0.477868 -0.223247 2.404916
#
# ...

# %%
if __name__ == "__main__":                
    filename = "/home/luluvyd/corpus/GloVe/vocab.txt"
    
    words = []
    freq = []
    with open(filename, 'r') as file: 
        for line in file: 
            l = line.split()
            words.append(l[0])
            freq.append(l[1])
    file.close()

# %%
print("number of unique words are : " + str(len(words)))
# Out:
# number of unique words are : 71290

# %%
# indexes = np.arange(len(words))
# width = 0.005

# plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

# plt.bar(indexes, freq, width)
# plt.xticks(indexes + width, words)
# plt.show()


# plot of frequency distribution 
sns.set(color_codes=True)
sns.distplot(np.array(freq).astype(int));
plt.show()
# Out:
# /home/luluvyd/anaconda3/lib/python3.5/site-packages/scipy/stats/stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
